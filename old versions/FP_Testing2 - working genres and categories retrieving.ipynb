# %% [markdown]
# # WRAPPER & LIBRARIES

# %% [markdown]
# ## INSTALLING WRAPPER & LIBRARIES

# %%
# pip install python-steam-api
# pip install googletrans==4.0.0-rc1

# Un wrapper en Python est une couche d'abstraction qui facilite l'utilisation d'une fonctionnalité ou d'une API externe dans votre programme Python en fournissant une interface plus simple 
# et en gérant les détails d'interaction avec cette fonctionnalité externe.

# %% [markdown]
# ## LOADING LIBRARIES

# %%
# **************************************************************************************
# LIBRARIES ****************************************************************************
# **************************************************************************************

# General-purpose libraries for operating system interactions, JSON data manipulation, and date/time handling.
import os  # Interact with the operating system
import json  # Work with JSON data
from random import randint  # Generate random integers
from time import sleep  # Introduce delays in code execution

from datetime import datetime, timedelta  # Manipulate dates and times
# **************************************************************************************

# Fundamental scientific computing libraries like NumPy and Pandas.
import numpy as np  # Fundamental package for scientific computing
import pandas as pd  # Data manipulation library
# **************************************************************************************

# **************************************************************************************
# **************************************************************************************

# Specialized libraries for scientific computing, namely SciPy
import scipy  # Scientific computing and technical computing library
import scipy.stats as st
# **************************************************************************************

# Web-related tasks, such as making HTTP requests, parsing HTML/XML data, and web scraping
import requests  # Perform HTTP requests
from bs4 import BeautifulSoup  # Parse HTML and XML data
# **************************************************************************************

# String operations
import regex as re
import string
from nltk.corpus import stopwords

# Pretty-print Python data structures
import pprint
# **************************************************************************************

# Visualization oriented
import matplotlib.pyplot as plt  # Create static visualizations
import seaborn as sns  # Statistical data visualization
from plotly import express as px  # Create interactive plots and charts

# **************************************************************************************
# **************************************************************************************

# Machine learning : preprocessing, dimensionality reduction, one-hot encoding, and clustering
import sklearn  # Machine learning library

from sklearn import svm

from sklearn.model_selection import train_test_split, cross_val_score

from sklearn.preprocessing import StandardScaler  # Standardize features
# One-hot encode categorical features
from sklearn.preprocessing import OneHotEncoder

from sklearn.decomposition import PCA  # Perform dimensionality reduction
from sklearn.cluster import KMeans  # Perform clustering

from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    precision_recall_curve, roc_curve, roc_auc_score
)


# Handling Imbalanced Datasets
import imblearn  # Handle imbalanced datasets in machine learning

# **************************************************************************************
# **************************************************************************************

# Web Scraping
import scrapy  # Web scraping framework

# Saving Stuff
import pickle

# Translating
from googletrans import Translator


# Deep Learning
# import pytorch  # Deep learning library

# **************************************************************************************
# FUNCTIONS ****************************************************************************
# **************************************************************************************

# from functions import scoring (name of function)

# %% [markdown]
# # API CONFIG

# %%
from steam import Steam  # Steam API Library
from decouple import config

# Retrieves my STEAM_API_KEY in my environnement variables
KEY = config("STEAM_API_KEY")
# Creates a class "Steam" based on the API KEY previously retrieved
steam = Steam(KEY)

# %%
friends_list = steam.users.get_user_friends_list("76561198084178563")
friends_list
# Out:
# {'friends': [{'steamid': '76561198077061193',
#    'communityvisibilitystate': 3,
#    'profilestate': 1,
#    'personaname': 'Blako99',
#    'commentpermission': 1,
#    'profileurl': 'https://steamcommunity.com/profiles/76561198077061193/',
#    'avatar': 'https://avatars.steamstatic.com/cd0b8c1a922ff9a723b7666b27cd7cb8feb74f6a.jpg',
#    'avatarmedium': 'https://avatars.steamstatic.com/cd0b8c1a922ff9a723b7666b27cd7cb8feb74f6a_medium.jpg',
#    'avatarfull': 'https://avatars.steamstatic.com/cd0b8c1a922ff9a723b7666b27cd7cb8feb74f6a_full.jpg',
#    'avatarhash': 'cd0b8c1a922ff9a723b7666b27cd7cb8feb74f6a',
#    'lastlogoff': 1685572564,
#    'personastate': 0,
#    'primaryclanid': '103582791438880304',
#    'timecreated': 1354116192,
#    'personastateflags': 0,
#    'relationship': 'friend',
#    'friend_since': 1453580166},
#   {'steamid': '76561197961064971',
#    'communityvisibilitystate': 3,
#    'profilestate': 1,
#    'personaname': 'Pastek',
#    'commentpermission': 1,
#    'profileurl': 'https://steamcommunity.com/id/BoFPastek/',
#    'avatar': 'https://avatars.steamstatic.com/1ee3b98c71785486a9b89ae2ef6f3a2ad3ef1919.jpg',
#    'avatarmedium': 'https://avatars.steamstatic.com/1ee3b98c71785486a9b89ae2ef6f3a2ad3ef1919_medium.jpg',
#    'avatarfull': 'https://avatars.steamstatic.com/1ee3b98c71785486a9b89ae2ef6f3a2ad3ef1919_full.jpg',
#    'avatarhash': '1ee3b98c71785486a9b89ae2ef6f3a2ad3ef1919',
#    'lastlogoff': 1685892056,
#    'personastate': 0,
#    'primaryclanid': '103582791429521408',
#    'timecreated': 1063987237,
#    'personastateflags': 0,
#    'relationship': 'friend',
#    'friend_since': 1361203077},
#   {'steamid': '76561198046891914',
#    'communityvisibilitystate': 3,
#    'profilestate': 1,
#    'personaname': 'Hawk',
#    'commentpermission': 1,
#    'profileurl': 'https://steamcommunity.com/id/koqonfais/',
#    'avatar': 'https://avatars.steamstatic.com/54d7cc914930ad90ef858bb0d845a6b7b50dbc39.jpg',
#    'avatarmedium': 'https://avatars.steamstatic.com/54d7cc914930ad90ef858bb0d845a6b7b50dbc39_medium.jpg',
#    'avatarfull': 'https://avatars.steamstatic.com/54d7cc914930ad90ef858bb0d845a6b7b50dbc39_full.jpg',
#    'avatarhash': '54d7cc914930ad90ef858bb0d845a6b7b50dbc39',
#    'lastlogoff': 1685925149,
#    'personastate': 0,
#    'primaryclanid': '103582791437768734',
#    'timecreated': 1313328123,
#    'personastateflags': 0,
#    'loccountrycode': 'NO',
#    'locstatecode': '08',
#    'relationship': 'friend',
#    'friend_since': 1408644248},
#   {'steamid': '76561198049485855',
#    'communityvisibilitystate': 3,
#    'profilestate': 1,
#    'personaname': '다미앙',
#    'profileurl': 'https://steamcommunity.com/id/damisback/',
#    'avatar': 'https://avatars.steamstatic.com/11f09007801b927c44e234aa6bd7e5bb33281358.jpg',
#    'avatarmedium': 'https://avatars.steamstatic.com/11f09007801b927c44e234aa6bd7e5bb33281358_medium.jpg',
#    'avatarfull': 'https://avatars.steamstatic.com/11f09007801b927c44e234aa6bd7e5bb33281358_full.jpg',
#    'avatarhash': '11f09007801b927c44e234aa6bd7e5bb33281358',
#    'lastlogoff': 1684950855,
#    'personastate': 0,
#    'primaryclanid': '103582791429521408',
#    'timecreated': 1316905658,
#    'personastateflags': 0,
#    'loccountrycode': 'FR',
#    'locstatecode': 'A8',
#    'relationship': 'friend',
#    'friend_since': 1366405459},
#   {'steamid': '76561198046866024',
#    'communityvisibilitystate': 3,
#    'profilestate': 1,
#    'personaname': 'Skye',
#    'profileurl': 'https://steamcommunity.com/profiles/76561198046866024/',
#    'avatar': 'https://avatars.steamstatic.com/156c3260ccdfc26dafc740a4059e9b1820670c0a.jpg',
#    'avatarmedium': 'https://avatars.steamstatic.com/156c3260ccdfc26dafc740a4059e9b1820670c0a_medium.jpg',
#    'avatarfull': 'https://avatars.steamstatic.com/156c3260ccdfc26dafc740a4059e9b1820670c0a_full.jpg',
#    'avatarhash': '156c3260ccdfc26dafc740a4059e9b1820670c0a',
#    'lastlogoff': 1496618709,
#    'personastate': 0,
#    'primaryclanid': '103582791429521408',
#    'timecreated': 1313276821,
#    'personastateflags': 0,
#    'relationship': 'friend',
#    'friend_since': 1401307239},
#   {'steamid': '76561197988856692',
#    'communityvisibilitystate': 1,
#    'profilestate': 1,
#    'personaname': 'CCJJ',
#    'commentpermission': 1,
#    'profileurl': 'https://steamcommunity.com/id/KOOJJJ/',
#    'avatar': 'https://avatars.steamstatic.com/0a01125c470e608e772e687d6050e299a4bf5f43.jpg',
#    'avatarmedium': 'https://avatars.steamstatic.com/0a01125c470e608e772e687d6050e299a4bf5f43_medium.jpg',
#    'avatarfull': 'https://avatars.steamstatic.com/0a01125c470e608e772e687d6050e299a4bf5f43_full.jpg',
#    'avatarhash': '0a01125c470e608e772e687d6050e299a4bf5f43',
#    'lastlogoff': 1667583046,
#    'personastate': 0,
#    'personastateflags': 0,
#    'relationship': 'friend',
#    'friend_since': 1403805053},
#   {'steamid': '76561197962123282',
#    'communityvisibilitystate': 3,
#    'profilestate': 1,
#    'personaname': '원숭이 D. 재이',
#    'profileurl': 'https://steamcommunity.com/profiles/76561197962123282/',
#    'avatar': 'https://avatars.steamstatic.com/81dcafb0732750690bf855ac3ef6da52852696c4.jpg',
#    'avatarmedium': 'https://avatars.steamstatic.com/81dcafb0732750690bf855ac3ef6da52852696c4_medium.jpg',
#    'avatarfull': 'https://avatars.steamstatic.com/81dcafb0732750690bf855ac3ef6da52852696c4_full.jpg',
#    'avatarhash': '81dcafb0732750690bf855ac3ef6da52852696c4',
#    'lastlogoff': 1685910406,
#    'personastate': 0,
#    'primaryclanid': '103582791435006233',
#    'timecreated': 1066480956,
#    'personastateflags': 0,
#    'relationship': 'friend',
#    'friend_since': 1367587530},
#   {'steamid': '76561198053172808',
#    'communityvisibilitystate': 3,
#    'profilestate': 1,
#    'personaname': 'QdC',
#    'commentpermission': 2,
#    'profileurl': 'https://steamcommunity.com/profiles/76561198053172808/',
#    'avatar': 'https://avatars.steamstatic.com/a9793fdaa6e2a5b6b723249db482bd56dd69e20b.jpg',
#    'avatarmedium': 'https://avatars.steamstatic.com/a9793fdaa6e2a5b6b723249db482bd56dd69e20b_medium.jpg',
#    'avatarfull': 'https://avatars.steamstatic.com/a9793fdaa6e2a5b6b723249db482bd56dd69e20b_full.jpg',
#    'avatarhash': 'a9793fdaa6e2a5b6b723249db482bd56dd69e20b',
#    'lastlogoff': 1685077560,
#    'personastate': 0,
#    'primaryclanid': '103582791434002033',
#    'timecreated': 1321991237,
#    'personastateflags': 0,
#    'relationship': 'friend',
#    'friend_since': 1366405527},
#   {'steamid': '76561197979183274',
#    'communityvisibilitystate': 3,
#    'profilestate': 1,
#    'personaname': 'imSOStoned',
#    'profileurl': 'https://steamcommunity.com/profiles/76561197979183274/',
#    'avatar': 'https://avatars.steamstatic.com/934ad845ae2e7806074693a416c4a2de1bef5b0c.jpg',
#    'avatarmedium': 'https://avatars.steamstatic.com/934ad845ae2e7806074693a416c4a2de1bef5b0c_medium.jpg',
#    'avatarfull': 'https://avatars.steamstatic.com/934ad845ae2e7806074693a416c4a2de1bef5b0c_full.jpg',
#    'avatarhash': '934ad845ae2e7806074693a416c4a2de1bef5b0c',
#    'lastlogoff': 1685747281,
#    'personastate': 0,
#    'realname': 'Pipo',
#    'primaryclanid': '103582791429639803',
#    'timecreated': 1131823555,
#    'personastateflags': 0,
#    'loccountrycode': 'FR',
#    'relationship': 'friend',
#    'friend_since': 1361213106},
#   {'steamid': '76561198134680248',
#    'communityvisibilitystate': 3,
#    'profilestate': 1,
#    'personaname': 'fantaWINSTON',
#    'profileurl': 'https://steamcommunity.com/profiles/76561198134680248/',
#    'avatar': 'https://avatars.steamstatic.com/0169725260c43c3a589a1accf36b92bde573c529.jpg',
#    'avatarmedium': 'https://avatars.steamstatic.com/0169725260c43c3a589a1accf36b92bde573c529_medium.jpg',
#    'avatarfull': 'https://avatars.steamstatic.com/0169725260c43c3a589a1accf36b92bde573c529_full.jpg',
#    'avatarhash': '0169725260c43c3a589a1accf36b92bde573c529',
#    'lastlogoff': 1685348636,
#    'personastate': 0,
#    'primaryclanid': '103582791429521408',
#    'timecreated': 1398547255,
#    'personastateflags': 0,
#    'relationship': 'friend',
#    'friend_since': 1431881909},
#   {'steamid': '76561198134289195',
#    'communityvisibilitystate': 3,
#    'profilestate': 1,
#    'personaname': 'Belette Blanche',
#    'profileurl': 'https://steamcommunity.com/id/BeletteBlancheTwitch/',
#    'avatar': 'https://avatars.steamstatic.com/77b3f550298765b388fa945d3b748c451ee4d44a.jpg',
#    'avatarmedium': 'https://avatars.steamstatic.com/77b3f550298765b388fa945d3b748c451ee4d44a_medium.jpg',
#    'avatarfull': 'https://avatars.steamstatic.com/77b3f550298765b388fa945d3b748c451ee4d44a_full.jpg',
#    'avatarhash': '77b3f550298765b388fa945d3b748c451ee4d44a',
#    'lastlogoff': 1685949485,
#    'personastate': 0,
#    'primaryclanid': '103582791429521408',
#    'timecreated': 1398265070,
#    'personastateflags': 0,
#    'loccountrycode': 'FR',
#    'relationship': 'friend',
#    'friend_since': 1625754012},
#   {'steamid': '76561197987339465',
#    'communityvisibilitystate': 3,
#    'profilestate': 1,
#    'personaname': 'XnodɐɥϽ',
#    'commentpermission': 2,
#    'profileurl': 'https://steamcommunity.com/id/ChapouX/',
#    'avatar': 'https://avatars.steamstatic.com/b62c5a66795fee2e6abe2e4b3548698cb87a51bc.jpg',
#    'avatarmedium': 'https://avatars.steamstatic.com/b62c5a66795fee2e6abe2e4b3548698cb87a51bc_medium.jpg',
#    'avatarfull': 'https://avatars.steamstatic.com/b62c5a66795fee2e6abe2e4b3548698cb87a51bc_full.jpg',
#    'avatarhash': 'b62c5a66795fee2e6abe2e4b3548698cb87a51bc',
#    'lastlogoff': 1685830768,
#    'personastate': 0,
#    'primaryclanid': '103582791432722533',
#    'timecreated': 1168174996,
#    'personastateflags': 0,
#    'loccountrycode': 'FR',
#    'locstatecode': 'B9',
#    'relationship': 'friend',
#    'friend_since': 1365278887},
#   {'steamid': '76561199131699234',
#    'communityvisibilitystate': 3,
#    'profilestate': 1,
#    'personaname': 'Dziahalla',
#    'commentpermission': 1,
#    'profileurl': 'https://steamcommunity.com/id/Kelly22199229224/',
#    'avatar': 'https://avatars.steamstatic.com/f1fd495b0b53db94434a1bcd91da18d13a8ae454.jpg',
#    'avatarmedium': 'https://avatars.steamstatic.com/f1fd495b0b53db94434a1bcd91da18d13a8ae454_medium.jpg',
#    'avatarfull': 'https://avatars.steamstatic.com/f1fd495b0b53db94434a1bcd91da18d13a8ae454_full.jpg',
#    'avatarhash': 'f1fd495b0b53db94434a1bcd91da18d13a8ae454',
#    'personastate': 0,
#    'primaryclanid': '103582791429521408',
#    'timecreated': 1611004562,
#    'personastateflags': 0,
#    'loccountrycode': 'JP',
#    'locstatecode': '45',
#    'loccityid': 26048,
#    'relationship': 'friend',
#    'friend_since': 1642533934},
#   {'steamid': '76561198049637789',
#    'communityvisibilitystate': 3,
#    'profilestate': 1,
#    'personaname': 'Tevou',
#    'profileurl': 'https://steamcommunity.com/profiles/76561198049637789/',
#    'avatar': 'https://avatars.steamstatic.com/832f868ad58ec3381c7eb0e233991565f7344379.jpg',
#    'avatarmedium': 'https://avatars.steamstatic.com/832f868ad58ec3381c7eb0e233991565f7344379_medium.jpg',
#    'avatarfull': 'https://avatars.steamstatic.com/832f868ad58ec3381c7eb0e233991565f7344379_full.jpg',
#    'avatarhash': '832f868ad58ec3381c7eb0e233991565f7344379',
#    'lastlogoff': 1685529107,
#    'personastate': 0,
#    'primaryclanid': '103582791429521408',
#    'timecreated': 1317154130,
#    'personastateflags': 0,
#    'relationship': 'friend',
#    'friend_since': 1364946899},
#   {'steamid': '76561198074180087',
#    'communityvisibilitystate': 3,
#    'profilestate': 1,
#    'personaname': 'Sen',
#    'profileurl': 'https://steamcommunity.com/profiles/76561198074180087/',
#    'avatar': 'https://avatars.steamstatic.com/798e1e8f8dd4565f5d079b8eab01f84c317e99de.jpg',
#    'avatarmedium': 'https://avatars.steamstatic.com/798e1e8f8dd4565f5d079b8eab01f84c317e99de_medium.jpg',
#    'avatarfull': 'https://avatars.steamstatic.com/798e1e8f8dd4565f5d079b8eab01f84c317e99de_full.jpg',
#    'avatarhash': '798e1e8f8dd4565f5d079b8eab01f84c317e99de',
#    'lastlogoff': 1685907150,
#    'personastate': 0,
#    'primaryclanid': '103582791457256652',
#    'timecreated': 1351168992,
#    'personastateflags': 0,
#    'relationship': 'friend',
#    'friend_since': 1364424241},
#   {'steamid': '76561198005875315',
#    'communityvisibilitystate': 3,
#    'profilestate': 1,
#    'personaname': 'saint mike',
#    'profileurl': 'https://steamcommunity.com/id/roflolxd/',
#    'avatar': 'https://avatars.steamstatic.com/30dd5e935d50900070b55e9aad10593f4fc1435e.jpg',
#    'avatarmedium': 'https://avatars.steamstatic.com/30dd5e935d50900070b55e9aad10593f4fc1435e_medium.jpg',
#    'avatarfull': 'https://avatars.steamstatic.com/30dd5e935d50900070b55e9aad10593f4fc1435e_full.jpg',
#    'avatarhash': '30dd5e935d50900070b55e9aad10593f4fc1435e',
#    'lastlogoff': 1685917571,
#    'personastate': 1,
#    'primaryclanid': '103582791437978208',
#    'timecreated': 1233688730,
#    'personastateflags': 0,
#    'relationship': 'friend',
#    'friend_since': 1408644243},
#   {'steamid': '76561198084852659',
#    'communityvisibilitystate': 3,
#    'profilestate': 1,
#    'personaname': 'lunaa ッ',
#    'profileurl': 'https://steamcommunity.com/profiles/76561198084852659/',
#    'avatar': 'https://avatars.steamstatic.com/9905f9da2843a982919d2342949ccb6b402f4aba.jpg',
#    'avatarmedium': 'https://avatars.steamstatic.com/9905f9da2843a982919d2342949ccb6b402f4aba_medium.jpg',
#    'avatarfull': 'https://avatars.steamstatic.com/9905f9da2843a982919d2342949ccb6b402f4aba_full.jpg',
#    'avatarhash': '9905f9da2843a982919d2342949ccb6b402f4aba',
#    'lastlogoff': 1685957002,
#    'personastate': 0,
#    'realname': 'Marie',
#    'primaryclanid': '103582791434956396',
#    'timecreated': 1361788697,
#    'personastateflags': 0,
#    'loccountrycode': 'FR',
#    'relationship': 'friend',
#    'friend_since': 1452350489},
#   {'steamid': '76561198047943960',
#    'communityvisibilitystate': 3,
#    'profilestate': 1,
#    'personaname': 'Valden',
#    'commentpermission': 1,
#    'profileurl': 'https://steamcommunity.com/id/ValdenkX/',
#    'avatar': 'https://avatars.steamstatic.com/bd0ad16d18a92c93957e76053398f4a3a01e1295.jpg',
#    'avatarmedium': 'https://avatars.steamstatic.com/bd0ad16d18a92c93957e76053398f4a3a01e1295_medium.jpg',
#    'avatarfull': 'https://avatars.steamstatic.com/bd0ad16d18a92c93957e76053398f4a3a01e1295_full.jpg',
#    'avatarhash': 'bd0ad16d18a92c93957e76053398f4a3a01e1295',
#    'lastlogoff': 1685956109,
#    'personastate': 0,
#    'realname': '√∂∫∂ξϞ',
#    'primaryclanid': '103582791434431604',
#    'timecreated': 1314897582,
#    'personastateflags': 0,
#    'loccountrycode': 'BE',
#    'locstatecode': '04',
#    'loccityid': 6430,
#    'relationship': 'friend',
#    'friend_since': 1452204519}]}

# %%
my_steam_id = 76561198084178563
my_acc_name = "steaaminn"

test_steam_id = 76561198995017863
test_persona_name = "the12thchairman"

pipo = 76561197979183274
qays = 76561197961064971

# %% [markdown]
# # GET USER'S STEAM_ID

# %%
# user_steam_id

# arguments: user_steam_id (input)
# user_steam_id = input("Please enter your Steam ID : ")

user_steam_id = 76561197961064971
print("Your Steam ID is :", user_steam_id)
# Out:
# Your Steam ID is : 76561197961064971

# %%
# user_details_from_steam_id

# arguments: steam_id
user_details = steam.users.get_user_details(user_steam_id)
pprint.pprint(user_details)
# Out:
# {'player': {'avatar': 'https://avatars.steamstatic.com/1ee3b98c71785486a9b89ae2ef6f3a2ad3ef1919.jpg',
#             'avatarfull': 'https://avatars.steamstatic.com/1ee3b98c71785486a9b89ae2ef6f3a2ad3ef1919_full.jpg',
#             'avatarhash': '1ee3b98c71785486a9b89ae2ef6f3a2ad3ef1919',
#             'avatarmedium': 'https://avatars.steamstatic.com/1ee3b98c71785486a9b89ae2ef6f3a2ad3ef1919_medium.jpg',
#             'commentpermission': 1,
#             'communityvisibilitystate': 3,
#             'lastlogoff': 1685892056,
#             'personaname': 'Pastek',
#             'personastate': 0,
#             'personastateflags': 0,
#             'primaryclanid': '103582791429521408',
#             'profilestate': 1,
#             'profileurl': 'https://steamcommunity.com/id/BoFPastek/',
#             'steamid': '76561197961064971',
#             'timecreated': 1063987237}}

# %%
# persona_name & persona_location

persona_name = ""
persona_location = ""

try:
    persona_name = user_details["player"]["personaname"]
    print("Persona Name:", persona_name)
except KeyError:
    print("Persona Name not found.")

try:
    persona_location = user_details["player"]["loccountrycode"]
    print("Persona Location:", persona_location)
except KeyError:
    print("Persona Location not found.")
# Out:
# Persona Name: Pastek
# Persona Location not found.

# %% [markdown]
# ### ***Improvement Proposal : retrieve ID based on account name + based on actual nickname aka alias***

# %%
# UPDATE 1
# ************************************
# # based on account name
# ************************************
# user_acc_name = input("Please enter your steam account name: ")
# user_acc_info = steam.users.search_user(user_acc_name)
# user_steam_id = user_acc_info['player']['steamid']
# print(user_steam_id)

# user_choice = input("Souhaitez-vous indiquer votre ID Steam ou votre nom ? (steam/nom): ")

# if user_choice.lower() == "steam":
#     steam_id = input("Veuillez entrer votre ID Steam : ")
#     print("Vous avez choisi d'indiquer votre ID Steam :", steam_id)

# elif user_choice.lower() == "nom":
#     nom = input("Veuillez entrer votre nom : ")
#     print("Vous avez choisi d'indiquer votre nom :", nom)

# else:
#     print("Choix invalide. Veuillez sélectionner 'steam' ou 'nom'.")


# UPDATE 2
# ************************************
#  based on actual nickname aka alias
# ************************************

# user_alias_name = input("Please enter your steam nickname aka alias: ")
# user_acc_info = steam.users.search_user(user_alias_name)
# user_steam_id = user_acc_info['player']['steamid']
# print(user_steam_id)

# %% [markdown]
# # GET USER'S TOP 10 MOST PLAYED GAMES

# %%
# user_games_library

user_games_library = steam.users.get_owned_games(user_steam_id)
pprint.pprint(user_games_library)
# Out:
# {'game_count': 97,
#  'games': [{'appid': 10,
#             'content_descriptorids': [2, 5],
#             'img_icon_url': '6b0312cda02f5f777efa2f3318c307ff9acafbb5',
#             'name': 'Counter-Strike',
#             'playtime_forever': 795,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 1403918646},
#            {'appid': 20,
#             'content_descriptorids': [2, 5],
#             'img_icon_url': '38ea7ebe3c1abbbbf4eabdbef174c41a972102b9',
#             'name': 'Team Fortress Classic',
#             'playtime_forever': 26,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 86400},
#            {'appid': 30,
#             'img_icon_url': 'aadc0ce51ff6ba2042d633f8ec033b0de62091d0',
#             'name': 'Day of Defeat',
#             'playtime_forever': 0,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 0},
#            {'appid': 40,
#             'img_icon_url': 'c525f76c8bc7353db4fd74b128c4ae2028426c2a',
#             'name': 'Deathmatch Classic',
#             'playtime_forever': 0,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 0},
#            {'appid': 50,
#             'img_icon_url': '04e81206c10e12416908c72c5f22aad411b3aeef',
#             'name': 'Half-Life: Opposing Force',
#             'playtime_forever': 0,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 0},
#            {'appid': 60,
#             'img_icon_url': '98c69e04cd59b838e05cb6980c12c05874c6419e',
#             'name': 'Ricochet',
#             'playtime_forever': 0,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 0},
#            {'appid': 70,
#             'img_icon_url': '95be6d131fc61f145797317ca437c9765f24b41c',
#             'name': 'Half-Life',
#             'playtime_forever': 0,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 0},
#            {'appid': 130,
#             'img_icon_url': 'b06fdee488b3220362c11704be4edad82abeed08',
#             'name': 'Half-Life: Blue Shift',
#             'playtime_forever': 0,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 0},
#            {'appid': 220,
#             'has_community_visible_stats': True,
#             'img_icon_url': 'fcfb366051782b8ebf2aa297f3b746395858cb62',
#             'name': 'Half-Life 2',
#             'playtime_forever': 0,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 0},
#            {'appid': 340,
#             'img_icon_url': '795e85364189511f4990861b578084deef086cb1',
#             'name': 'Half-Life 2: Lost Coast',
#             'playtime_forever': 0,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 0},
#            {'appid': 16810,
#             'img_icon_url': '321fb29a4c82b4ccc3587d9967a3b9f8e3933a5a',
#             'name': "Sid Meier's Civilization IV: Colonization",
#             'playtime_forever': 79,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 1455481104},
#            {'appid': 105600,
#             'has_community_visible_stats': True,
#             'img_icon_url': '858961e95fbf869f136e1770d586e0caefd4cfac',
#             'name': 'Terraria',
#             'playtime_forever': 0,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 0},
#            {'appid': 200910,
#             'has_community_visible_stats': True,
#             'img_icon_url': '7f35c4662470a8ff8a726ab4d8847049b1414bc8',
#             'name': 'Before the Echo',
#             'playtime_forever': 43,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 1322208000},
#            {'appid': 48000,
#             'has_community_visible_stats': True,
#             'img_icon_url': '463f57855017564301b17050fba73804b3bd86d6',
#             'name': 'LIMBO',
#             'playtime_forever': 0,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 0},
#            {'appid': 107100,
#             'has_community_visible_stats': True,
#             'img_icon_url': '8377b4460f19465c261673f76f2656bdb3288273',
#             'name': 'Bastion',
#             'playtime_forever': 86,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 1474058883},
#            {'appid': 113200,
#             'has_community_visible_stats': True,
#             'img_icon_url': '383cf045ca20625db18f68ef5e95169012118b9e',
#             'name': 'The Binding of Isaac',
#             'playtime_forever': 59,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 1423602121},
#            {'appid': 730,
#             'content_descriptorids': [2, 5],
#             'has_community_visible_stats': True,
#             'img_icon_url': '69f7ebe2735c366c65c0b33dae00e12dc40edbe4',
#             'name': 'Counter-Strike: Global Offensive',
#             'playtime_forever': 41370,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 19,
#             'rtime_last_played': 1675442623},
#            {'appid': 49520,
#             'has_community_visible_stats': True,
#             'img_icon_url': 'a3f4945226e69b6196074df4c776e342d3e5a3be',
#             'name': 'Borderlands 2',
#             'playtime_forever': 122,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 1368601200},
#            {'appid': 200510,
#             'has_community_visible_stats': True,
#             'img_icon_url': '48be2fee1d0d511b5c7313e1359beafd36ea92ed',
#             'name': 'XCOM: Enemy Unknown',
#             'playtime_forever': 29,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 29,
#             'rtime_last_played': 1677006781},
#            {'appid': 212070,
#             'has_community_visible_stats': True,
#             'img_icon_url': '1d239792f0cd35ace45c219fd2985340539feacc',
#             'name': 'Star Conflict',
#             'playtime_forever': 44,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 1456684999},
#            {'appid': 236390,
#             'has_community_visible_stats': True,
#             'img_icon_url': 'c69fbafb6e9891314cc5df0fe6a659612c289bf9',
#             'name': 'War Thunder',
#             'playtime_forever': 278,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 1420401460},
#            {'appid': 238960,
#             'content_descriptorids': [1, 2, 5],
#             'has_community_visible_stats': True,
#             'img_icon_url': '1110764aac57ac28d7ffd8c43071c75d5482a9c9',
#             'name': 'Path of Exile',
#             'playtime_forever': 91380,
#             'playtime_linux_forever': 4479,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 65808,
#             'rtime_last_played': 1683062319},
#            {'appid': 202090,
#             'img_icon_url': 'd7d8efb579d5eeef0fd1457788a40f8183ceef8b',
#             'name': 'Magicka: Wizard Wars',
#             'playtime_forever': 1221,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 1436384210},
#            {'appid': 230190,
#             'has_community_visible_stats': True,
#             'img_icon_url': '9fd8f2fec6b8967dc79d87b2a704f866c02cfcef',
#             'name': 'War for the Overworld',
#             'playtime_forever': 701,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 1440184286},
#            {'appid': 35720,
#             'has_community_visible_stats': True,
#             'img_icon_url': '061ecbbd7c70ae1c052377bad136c7759cbb708d',
#             'name': 'Trine 2',
#             'playtime_forever': 33,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 1446983170},
#            {'appid': 242760,
#             'content_descriptorids': [2, 5],
#             'has_community_visible_stats': True,
#             'img_icon_url': '3a6847f6ac5879e48531db52261771d5e22904ac',
#             'name': 'The Forest',
#             'playtime_forever': 841,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 841,
#             'rtime_last_played': 1639673663},
#            {'appid': 39140,
#             'has_community_visible_stats': True,
#             'img_icon_url': 'dc89ce8f07d5ec36a5617a66fe16e3541d2cc172',
#             'name': 'FINAL FANTASY VII',
#             'playtime_forever': 66,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 1373058614},
#            {'appid': 213850,
#             'has_community_visible_stats': True,
#             'img_icon_url': '350d7326abee67845350521cbd5ed9b6fb81337f',
#             'name': 'Magic 2014 ',
#             'playtime_forever': 511,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 1373665522},
#            {'appid': 107410,
#             'content_descriptorids': [2, 5],
#             'has_community_visible_stats': True,
#             'has_leaderboards': True,
#             'img_icon_url': '3212af52faf994c558bd622cb0f360c1ef295a6b',
#             'name': 'Arma 3',
#             'playtime_forever': 381,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 1391715407},
#            {'appid': 108600,
#             'img_icon_url': '2bd4642ae337e378e7b04a19d19683425c5f81a4',
#             'name': 'Project Zomboid',
#             'playtime_forever': 969,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 969,
#             'rtime_last_played': 1642867897},
#            {'appid': 226840,
#             'has_community_visible_stats': True,
#             'img_icon_url': '06f134e787a2dd9022c0e8514ab918f4530665a8',
#             'name': 'Age of Wonders III',
#             'playtime_forever': 0,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 0},
#            {'appid': 221100,
#             'content_descriptorids': [2, 5],
#             'has_community_visible_stats': True,
#             'img_icon_url': '16a985dfee9b093d76a0ffc4cf4c77ba20c2eb0d',
#             'name': 'DayZ',
#             'playtime_forever': 488,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 1405466145},
#            {'appid': 271590,
#             'content_descriptorids': [5],
#             'has_community_visible_stats': True,
#             'img_icon_url': '1e72f87eb927fa1485e68aefaff23c7fd7178251',
#             'name': 'Grand Theft Auto V',
#             'playtime_forever': 342,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 1455443695},
#            {'appid': 225840,
#             'img_icon_url': 'b552055c69f4b4b05195b72805ed0bff09cf1e93',
#             'name': 'Sven Co-op',
#             'playtime_forever': 29,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 1454187575},
#            {'appid': 200110,
#             'has_community_visible_stats': True,
#             'img_icon_url': '5059f6d2b9c87f10a631fcdcbed1020f7aae0ef9',
#             'name': 'Nosgoth',
#             'playtime_forever': 1394,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 1424312514},
#            {'appid': 285310,
#             'img_icon_url': '5b6883725dc44e6547708ca7cae1d2ded82d1dff',
#             'name': 'RollerCoaster Tycoon: Deluxe',
#             'playtime_forever': 134,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 134,
#             'rtime_last_played': 1662138301},
#            {'appid': 222900,
#             'has_community_visible_stats': True,
#             'img_icon_url': 'eeca961216745840443d87373f907d1e6e4ca764',
#             'name': 'Dead Island: Epidemic',
#             'playtime_forever': 143,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 1441036156},
#            {'appid': 323370,
#             'content_descriptorids': [5],
#             'img_icon_url': 'cbfb0fe6ce60b1fa651abe643215f7e721bd81fd',
#             'name': 'TERA',
#             'playtime_forever': 0,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 0},
#            {'appid': 327400,
#             'img_icon_url': 'd2c030a782d67f51a69800ba8cec58c39724cad3',
#             'name': "Sid Meier's Colonization (Classic)",
#             'playtime_forever': 11,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 1455218603},
#            {'appid': 332500,
#             'img_icon_url': 'b5d0d35b1719afef7fb5374ac0f65aa368f1d3f2',
#             'name': 'GRAV',
#             'playtime_forever': 20,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 1420826904},
#            {'appid': 346110,
#             'has_community_visible_stats': True,
#             'img_icon_url': 'fef1799533131c10f538d2dd697bbbd89e663265',
#             'name': 'ARK: Survival Evolved',
#             'playtime_forever': 807,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 1435511476},
#            {'appid': 407530,
#             'img_icon_url': '807c673cddebbfee0700a947a75f4872ad136e9b',
#             'name': 'ARK: Survival Of The Fittest',
#             'playtime_forever': 0,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 0},
#            {'appid': 230230,
#             'has_community_visible_stats': True,
#             'img_icon_url': 'ca9cdafd4257253dba68babeed300874190fbbff',
#             'name': 'Divinity: Original Sin (Classic)',
#             'playtime_forever': 0,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 0},
#            {'appid': 373420,
#             'has_community_visible_stats': True,
#             'img_icon_url': '822ff912b2e464fbebbedf7a75ae1eb24921f16b',
#             'name': 'Divinity: Original Sin Enhanced Edition',
#             'playtime_forever': 927,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 1515627703},
#            {'appid': 386360,
#             'has_community_visible_stats': True,
#             'img_icon_url': '7ed9de7bbfab9accb81e47b84943e7478baf2f3a',
#             'name': 'SMITE',
#             'playtime_forever': 247,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 1443139481},
#            {'appid': 858460,
#             'img_icon_url': '20e160ebdeddbb45f1066f62797cee2dff94da95',
#             'name': 'SMITE - Public Test',
#             'playtime_forever': 0,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 0},
#            {'appid': 393420,
#             'img_icon_url': '6d5ae57f85d8d2af758afa89df4369da699900dc',
#             'name': 'Hurtworld',
#             'playtime_forever': 5771,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 1454105018},
#            {'appid': 620,
#             'has_community_visible_stats': True,
#             'has_leaderboards': True,
#             'img_icon_url': '2e478fc6874d06ae5baf0d147f6f21203291aa02',
#             'name': 'Portal 2',
#             'playtime_forever': 0,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 0},
#            {'appid': 252950,
#             'has_community_visible_stats': True,
#             'img_icon_url': '9ad6dd3d173523354385955b5fb2af87639c4163',
#             'name': 'Rocket League',
#             'playtime_forever': 2216,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 193,
#             'rtime_last_played': 1615487444},
#            {'appid': 236110,
#             'has_community_visible_stats': True,
#             'img_icon_url': '0ce07c2568f978a01c8ae5f4d9402c3253963641',
#             'name': 'Dungeon Defenders II',
#             'playtime_forever': 58,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 1444834497},
#            {'appid': 225540,
#             'has_community_visible_stats': True,
#             'img_icon_url': 'c82c69c8d616d9d273d749e3dd3bd7a0f9da594a',
#             'name': 'Just Cause 3',
#             'playtime_forever': 0,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 0},
#            {'appid': 425670,
#             'has_community_visible_stats': True,
#             'img_icon_url': '0a0a1afb61c95b48667047b44d1966d097f8221e',
#             'name': 'Seraph',
#             'playtime_forever': 138,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 1475177647},
#            {'appid': 268500,
#             'has_community_visible_stats': True,
#             'img_icon_url': 'f275aeb0b1b947262810569356a199848c643754',
#             'name': 'XCOM 2',
#             'playtime_forever': 0,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 0},
#            {'appid': 427270,
#             'has_community_visible_stats': True,
#             'img_icon_url': '5343b3d062ed6e5fe4c1a05c0de0a48b1e3cf094',
#             'name': 'Orcs Must Die! Unchained',
#             'playtime_forever': 181,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 1460249660},
#            {'appid': 427520,
#             'has_community_visible_stats': True,
#             'img_icon_url': '267f5a89f36ab287e600a4e7d4e73d3d11f0fd7d',
#             'name': 'Factorio',
#             'playtime_forever': 90,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 90,
#             'rtime_last_played': 1602018893},
#            {'appid': 275850,
#             'has_community_visible_stats': True,
#             'img_icon_url': 'fccb20f309ac5ae05b3cb4576a8a3357edf86f2e',
#             'name': "No Man's Sky",
#             'playtime_forever': 275,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 275,
#             'rtime_last_played': 1658930212},
#            {'appid': 207140,
#             'has_community_visible_stats': True,
#             'img_icon_url': '65cfa21149c415430fe36d83c23e079e6db476cc',
#             'name': 'SpeedRunners',
#             'playtime_forever': 526,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 1522842717},
#            {'appid': 464920,
#             'has_community_visible_stats': True,
#             'img_icon_url': '6c0bbf943ed725a16304161b89061ac1d37f6a2a',
#             'name': 'Surviving Mars',
#             'playtime_forever': 162,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 162,
#             'rtime_last_played': 1664542093},
#            {'appid': 427460,
#             'img_icon_url': '',
#             'name': 'Battlerite Public Test',
#             'playtime_forever': 0,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 0},
#            {'appid': 504370,
#             'img_icon_url': '943ec9894774f40c9863d0305c456a3c3b2f7c13',
#             'name': 'Battlerite',
#             'playtime_forever': 229,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 9,
#             'rtime_last_played': 1619969893},
#            {'appid': 517790,
#             'img_icon_url': '8ebd74d26d3ac7e81b18fa6baa99a5c8f69744fe',
#             'name': 'Caesar 3',
#             'playtime_forever': 86,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 86,
#             'rtime_last_played': 1599150397},
#            {'appid': 289070,
#             'has_community_visible_stats': True,
#             'img_icon_url': '9dc914132fec244adcede62fb8e7524a72a7398c',
#             'name': "Sid Meier's Civilization VI",
#             'playtime_forever': 136,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 136,
#             'rtime_last_played': 1664103212},
#            {'appid': 526870,
#             'img_icon_url': 'ee3406fe5ec813b1987ad67e37e5cd6fb4f620e6',
#             'name': 'Satisfactory',
#             'playtime_forever': 3080,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 3080,
#             'rtime_last_played': 1602958475},
#            {'appid': 588650,
#             'has_community_visible_stats': True,
#             'img_icon_url': 'a431361e5dae5fd6ac2433064b62b2a37abc38f1',
#             'name': 'Dead Cells',
#             'playtime_forever': 911,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 1538842666},
#            {'appid': 630100,
#             'img_icon_url': 'a6508d81099861636f59188db07f9349d885046a',
#             'name': 'SoulWorker',
#             'playtime_forever': 19,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 19,
#             'rtime_last_played': 1600885281},
#            {'appid': 674940,
#             'has_community_visible_stats': True,
#             'img_icon_url': '28bc7ba8952d488e01e7136126cbbc3b42ee443a',
#             'name': 'Stick Fight: The Game',
#             'playtime_forever': 125,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 1524050822},
#            {'appid': 435150,
#             'has_community_visible_stats': True,
#             'img_icon_url': '519a99caef7c5e2b4625c8c2fa0620fb66a752f3',
#             'name': 'Divinity: Original Sin 2',
#             'playtime_forever': 2300,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 1549656563},
#            {'appid': 739630,
#             'img_icon_url': '125673b382059f666ec81477173380a76e1df0be',
#             'name': 'Phasmophobia',
#             'playtime_forever': 923,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 923,
#             'rtime_last_played': 1666475145},
#            {'appid': 755790,
#             'content_descriptorids': [2, 5],
#             'img_icon_url': 'bff111ed4307fc769143eb3d652fb940c363e37e',
#             'name': 'Ring of Elysium',
#             'playtime_forever': 60,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 25,
#             'rtime_last_played': 1584900915},
#            {'appid': 813820,
#             'has_community_visible_stats': True,
#             'img_icon_url': '068664cf452a9f2388cf1ccf1f239fc967ff9629',
#             'name': 'Realm Royale Reforged',
#             'playtime_forever': 834,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 1543070227},
#            {'appid': 878760,
#             'img_icon_url': '068664cf452a9f2388cf1ccf1f239fc967ff9629',
#             'name': 'Realm Royale - Test Server',
#             'playtime_forever': 0,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 0},
#            {'appid': 360620,
#             'img_icon_url': 'bc438e2de9ef856e639a49041834c0cc7a5147fa',
#             'name': 'Spellsworn',
#             'playtime_forever': 39,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 39,
#             'rtime_last_played': 1600882173},
#            {'appid': 823130,
#             'img_icon_url': '920902c516d435c3d9a6c5ef92e3cd4372f9314b',
#             'name': 'Totally Accurate Battlegrounds',
#             'playtime_forever': 0,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 0},
#            {'appid': 544920,
#             'has_community_visible_stats': True,
#             'img_icon_url': 'ec8efa43138b3dd7c26d07c0e2527252fbdeeed5',
#             'name': 'Darwin Project',
#             'playtime_forever': 292,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 1530657150},
#            {'appid': 882100,
#             'content_descriptorids': [5],
#             'has_community_visible_stats': True,
#             'img_icon_url': 'dd8ae1a236af5d4a833f41aab2fdad902f454c63',
#             'name': 'XCOM: Chimera Squad',
#             'playtime_forever': 0,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 0},
#            {'appid': 892970,
#             'img_icon_url': '2f64c9a826e2c6cf3253fea4834c2e612db09143',
#             'name': 'Valheim',
#             'playtime_forever': 495,
#             'playtime_linux_forever': 1,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 494,
#             'rtime_last_played': 1612710729},
#            {'appid': 714010,
#             'has_community_visible_stats': True,
#             'has_leaderboards': True,
#             'img_icon_url': '6b048dc353ff0be1d60000169dd4f18e13a00b52',
#             'name': 'Aim Lab',
#             'playtime_forever': 43,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 8,
#             'rtime_last_played': 1614073312},
#            {'appid': 899770,
#             'content_descriptorids': [2, 5],
#             'img_icon_url': 'af127fa6337a3c44e52690b62f26530d520127f4',
#             'name': 'Last Epoch',
#             'playtime_forever': 1328,
#             'playtime_linux_forever': 614,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 713,
#             'rtime_last_played': 1680116221},
#            {'appid': 962130,
#             'has_community_visible_stats': True,
#             'img_icon_url': '0e598fd0dc10e3d85e5f244c62d0c41e4c8d96cc',
#             'name': 'Grounded',
#             'playtime_forever': 636,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 636,
#             'rtime_last_played': 1665756663},
#            {'appid': 1046930,
#             'img_icon_url': '1f6f64144e8cc371c5382660e48998dfbe0a708e',
#             'name': 'Dota Underlords',
#             'playtime_forever': 213,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 146,
#             'rtime_last_played': 1583435744},
#            {'appid': 1049590,
#             'img_icon_url': '221a491630f192b73941c755c4f833c4f34de2e1',
#             'name': 'Eternal Return',
#             'playtime_forever': 13,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 13,
#             'rtime_last_played': 1614074153},
#            {'appid': 761890,
#             'has_community_visible_stats': True,
#             'img_icon_url': 'c58d1e42e59a9c6cc57c8da69d944b37ba45a0e2',
#             'name': 'Albion Online',
#             'playtime_forever': 425,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 425,
#             'rtime_last_played': 1611863399},
#            {'appid': 1128810,
#             'has_community_visible_stats': True,
#             'img_icon_url': 'ecc6f7301e88a88e93edec1a3d4ddcc7ec9c5335',
#             'name': 'RISK: Global Domination',
#             'playtime_forever': 40,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 40,
#             'rtime_last_played': 1586456681},
#            {'appid': 1169040,
#             'has_community_visible_stats': True,
#             'img_icon_url': 'f74fcfc959bc4359e442840ba11479051be03e13',
#             'name': 'Necesse',
#             'playtime_forever': 428,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 428,
#             'rtime_last_played': 1678916168},
#            {'appid': 1063730,
#             'content_descriptorids': [2, 5],
#             'has_community_visible_stats': True,
#             'img_icon_url': '082cb546221edf8c9e68d0abda0421ce3c55ee71',
#             'name': 'New World',
#             'playtime_forever': 129,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 129,
#             'rtime_last_played': 1664314378},
#            {'appid': 1245620,
#             'content_descriptorids': [2, 5],
#             'has_community_visible_stats': True,
#             'img_icon_url': 'b6e290dd5a92ce98f89089a207733c70c41a1871',
#             'name': 'ELDEN RING',
#             'playtime_forever': 3699,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 3699,
#             'rtime_last_played': 1649262638},
#            {'appid': 582660,
#             'img_icon_url': 'bf5ccace0a692720984827bf042143d0d4b28a42',
#             'name': 'Black Desert',
#             'playtime_forever': 73,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 73,
#             'rtime_last_played': 1615208010},
#            {'appid': 1604030,
#             'img_icon_url': 'd18204000a839feb84393b3d860c17cd4a4b269c',
#             'name': 'V Rising',
#             'playtime_forever': 1411,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 1411,
#             'rtime_last_played': 1653502887},
#            {'appid': 1637320,
#             'has_community_visible_stats': True,
#             'has_leaderboards': True,
#             'img_icon_url': '4ecf3a011cf5eeb37d0072a1a182b7ea5140e3e2',
#             'name': 'Dome Keeper',
#             'playtime_forever': 129,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 129,
#             'rtime_last_played': 1664829753},
#            {'appid': 1466860,
#             'has_community_visible_stats': True,
#             'img_icon_url': '503acf3ef0503e24af6b5336012a1f585a2f955e',
#             'name': 'Age of Empires IV: Anniversary Edition',
#             'playtime_forever': 1042,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 1042,
#             'rtime_last_played': 1666547676},
#            {'appid': 1794680,
#             'has_community_visible_stats': True,
#             'img_icon_url': 'b09d9a388f5328ec977f7b45228ac8ae21a78c55',
#             'name': 'Vampire Survivors',
#             'playtime_forever': 401,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 401,
#             'rtime_last_played': 1646153072},
#            {'appid': 1818750,
#             'has_community_visible_stats': True,
#             'img_icon_url': 'b99e0727d4b37c022f33f8f72fada74c5108aac0',
#             'name': 'MultiVersus',
#             'playtime_forever': 107,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 107,
#             'rtime_last_played': 1660835065},
#            {'appid': 1599340,
#             'content_descriptorids': [1, 2, 5],
#             'has_community_visible_stats': True,
#             'img_icon_url': '4e4ef2862189e1f1d3052125fb1ed6cb42bcaaf8',
#             'name': 'Lost Ark',
#             'playtime_forever': 65,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 65,
#             'rtime_last_played': 1664347279},
#            {'appid': 1974050,
#             'img_icon_url': '77ce83c970c9f04b29a7381302fb35b152786c74',
#             'name': 'Torchlight: Infinite',
#             'playtime_forever': 175,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 175,
#             'rtime_last_played': 1682762128},
#            {'appid': 990080,
#             'has_community_visible_stats': True,
#             'img_icon_url': 'a9ecb94f249768d0ee5ccecbffe8d8c06d9bed59',
#             'name': 'Hogwarts Legacy',
#             'playtime_forever': 1098,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 1098,
#             'rtime_last_played': 1681921714},
#            {'appid': 440,
#             'content_descriptorids': [2, 5],
#             'has_community_visible_stats': True,
#             'has_leaderboards': True,
#             'img_icon_url': 'e3f595a92552da3d664ad00277fad2107345f743',
#             'name': 'Team Fortress 2',
#             'playtime_forever': 2288,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 0,
#             'rtime_last_played': 1553172683},
#            {'appid': 570,
#             'img_icon_url': '0bbb630d63262dd66d2fdd0f7d37e8661a410075',
#             'name': 'Dota 2',
#             'playtime_forever': 180723,
#             'playtime_linux_forever': 0,
#             'playtime_mac_forever': 0,
#             'playtime_windows_forever': 62729,
#             'rtime_last_played': 1666965989}]}

# %%
user_games_library["game_count"]
# Out:
# 97

# %%
# top_10_app_ids

if len(user_games_library) == 0:
    print("Error : Your games library seem to be empty.\nIt's then impossible to recommend you a new game based on your preferrences.\nSowy.")
else:
    # Orders all the games by "playtime_forever" in descending order
    sorted_games = sorted(
        user_games_library['games'], key=lambda x: x['playtime_forever'], reverse=True)

    # Retrieves app_idRécupère les "appid" des 10 premiers jeux avec le plus de "playtime_forever"
    top_10_apps_ids = [game['appid'] for game in sorted_games[:10]]
    print("Top 10 AppIDs:", top_10_apps_ids)
# Out:
# Top 10 AppIDs: [570, 238960, 730, 393420, 1245620, 526870, 435150, 440, 252950, 1604030]

# %%
# Quick recap

for game in sorted_games[:10]:
    app_id = game['appid']
    app_name = game['name']
    playtime_forever = game['playtime_forever']
    playtime_hours = playtime_forever / 60
    print("app_id:", app_id, " - ", app_name, " - Total Playtime:",
            playtime_forever, "or", round(playtime_hours), "hours.")
# Out:
# app_id: 570  -  Dota 2  - Total Playtime: 180723 or 3012 hours.
# app_id: 238960  -  Path of Exile  - Total Playtime: 91380 or 1523 hours.
# app_id: 730  -  Counter-Strike: Global Offensive  - Total Playtime: 41370 or 690 hours.
# app_id: 393420  -  Hurtworld  - Total Playtime: 5771 or 96 hours.
# app_id: 1245620  -  ELDEN RING  - Total Playtime: 3699 or 62 hours.
# app_id: 526870  -  Satisfactory  - Total Playtime: 3080 or 51 hours.
# app_id: 435150  -  Divinity: Original Sin 2  - Total Playtime: 2300 or 38 hours.
# app_id: 440  -  Team Fortress 2  - Total Playtime: 2288 or 38 hours.
# app_id: 252950  -  Rocket League  - Total Playtime: 2216 or 37 hours.
# app_id: 1604030  -  V Rising  - Total Playtime: 1411 or 24 hours.

# %% [markdown]
# # GET THE CORRESPONDING GAME GENRES FOR EACH GAME

# %%
top_10_apps_ids
# Out:
# [570, 238960, 730, 393420, 1245620, 526870, 435150, 440, 252950, 1604030]

# %% [markdown]
# ## ???

# %%
# # apps_details

# # arguments: app_id
# apps_details = []
# data = {}

# for app in top_10_apps_ids:
#     apps_details.append(steam.apps.get_app_details(app))
#     data = json.loads(steam.apps.get_app_details(top_10_apps_ids))
# pprint.pprint(apps_details)

# %% [markdown]
# ## ???

# %%
# apps_details

# arguments: app_id
app_details = []
apps_details = []

apps_data = {}


for app in top_10_apps_ids:
    
    app_details = steam.apps.get_app_details(app)
    apps_details.append(app_details)
    
    apps_data[app] = json.loads(app_details)

# %%
pprint.pprint(type(app_details))
app_details
# Out:
# <class 'str'>
# '{"1604030": {"success": true, "data": {"type": "game", "name": "V Rising", "steam_appid": 1604030, "required_age": 0, "is_free": false, "dlc": [1983900, 1983901, 1999270, 2358430], "detailed_description": "<strong>A Vampire Survival Experience</strong><br><br>Awaken as a weakened vampire after centuries of slumber. Hunt for blood to regain your strength while hiding from the scorching sun to survive. Rebuild your castle and convert humans into your loyal servants in a quest to raise your vampire empire. Make allies or enemies online or play solo locally, fend off holy soldiers, and wage war in a world of conflict. <br><br>Will you become the next Dracula?<h2 class=\\"bb_tag\\">A Gothic Open-World </h2><br>Explore a vast world teeming with mythical horrors and danger. Travel through lush forests, open countryside, and dark caverns to discover valuable resources, meeting friends and foes alike along the way. Traverse the world with vampire comrades or hunt solo as you pillage villages, raid bandits, and delve into the domains of supernatural beasts.<br><br><img src=\\"https://cdn.akamai.steamstatic.com/steam/apps/1604030/extras/OpenWorld01_1.gif?t=1684394834\\" /><h2 class=\\"bb_tag\\">Fear the light - Rule the night </h2><br>Stick to the shadows during the daytime, or the burning sunlight will turn you to ashes. Roam the night and prey on your victims in the darkness. As a vampire, you must quench your thirst for blood while planning your strategies around the day and nighttime.<br><br><img src=\\"https://cdn.akamai.steamstatic.com/steam/apps/1604030/extras/FearTheLightRuleTheNight_1__1_.gif?t=1684394834\\" /><h2 class=\\"bb_tag\\">Raise your Castle</h2> <br>Gather resources and discover ancient techniques to gain dark powers. Use your newly acquired knowledge to build a castle where you can store your loot and grow your army of darkness. Personalize your domain, exhibit your vampiric style and make sure to craft coffins for servants and friends. Strengthen your castle to protect your treasure hoard from vampire rivals.<br><br><img src=\\"https://cdn.akamai.steamstatic.com/steam/apps/1604030/extras/RaiseYourCastle_1.gif?t=1684394834\\" /><h2 class=\\"bb_tag\\">Compete or Cooperate </h2><br>Travel alone or explore the world with friends. Fighting side by side with other vampires will give you an advantage in the fight to conquer the greatest threats of Vardoran. Raid other players\\u2019 castles or play the diplomat in the game of blood, power, and betrayal. Compete or cooperate - the choice is yours.<br><br><img src=\\"https://cdn.akamai.steamstatic.com/steam/apps/1604030/extras/CompeteOrCooperate_3.gif?t=1684394834\\" /><h2 class=\\"bb_tag\\">Master your Vampire</h2><br>Learn and master an arsenal of deadly weapons and unholy abilities. In V Rising, you aim skill-shots and dodge projectiles using\\u200b precise\\u200b\\u200b \\u200bWASD controls \\u200band cursor-based\\u200b \\u200baiming - no click to move. Tailor your vampire to fit your play style by combining weapons with a variety of spells earned through vanquishing powerful foes. Master your skills and unleash your wicked powers.<br><br><img src=\\"https://cdn.akamai.steamstatic.com/steam/apps/1604030/extras/MasterYourVampire_1.gif?t=1684394834\\" />", "about_the_game": "<strong>A Vampire Survival Experience</strong><br><br>Awaken as a weakened vampire after centuries of slumber. Hunt for blood to regain your strength while hiding from the scorching sun to survive. Rebuild your castle and convert humans into your loyal servants in a quest to raise your vampire empire. Make allies or enemies online or play solo locally, fend off holy soldiers, and wage war in a world of conflict. <br><br>Will you become the next Dracula?<h2 class=\\"bb_tag\\">A Gothic Open-World </h2><br>Explore a vast world teeming with mythical horrors and danger. Travel through lush forests, open countryside, and dark caverns to discover valuable resources, meeting friends and foes alike along the w ...

# %%
pprint.pprint(type(apps_details))
apps_details
# Out:
# <class 'list'>
# ['{"570": {"success": true, "data": {"type": "game", "name": "Dota 2", "steam_appid": 570, "required_age": 0, "is_free": true, "dlc": [1241930, 652720], "detailed_description": "<strong>The most-played game on Steam.</strong><br>Every day, millions of players worldwide enter battle as one of over a hundred Dota heroes. And no matter if it\'s their 10th hour of play or 1,000th, there\'s always something new to discover. With regular updates that ensure a constant evolution of gameplay, features, and heroes, Dota 2 has truly taken on a life of its own.<br><br><strong>One Battlefield. Infinite Possibilities.</strong><br>When it comes to diversity of heroes, abilities, and powerful items, Dota boasts an endless array\\u2014no two games are the same. Any hero can fill multiple roles, and there\'s an abundance of items to help meet the needs of each game. Dota doesn\'t provide limitations on how to play, it empowers you to express your own style.<br><br><strong>All heroes are free.</strong><br>Competitive balance is Dota\'s crown jewel, and to ensure everyone is playing on an even field, the core content of the game\\u2014like the vast pool of heroes\\u2014is available to all players. Fans can collect cosmetics for heroes and fun add-ons for the world they inhabit, but everything you need to play is already included before you join your first match.<br><br><strong>Bring your friends and party up.</strong><br>Dota is deep, and constantly evolving, but it\'s never too late to join. <br>Learn the ropes playing co-op vs. bots. Sharpen your skills in the hero demo mode. Jump into the behavior- and skill-based matchmaking system that ensures you\'ll <br>be matched with the right players each game.", "about_the_game": "<strong>The most-played game on Steam.</strong><br>Every day, millions of players worldwide enter battle as one of over a hundred Dota heroes. And no matter if it\'s their 10th hour of play or 1,000th, there\'s always something new to discover. With regular updates that ensure a constant evolution of gameplay, features, and heroes, Dota 2 has truly taken on a life of its own.<br><br><strong>One Battlefield. Infinite Possibilities.</strong><br>When it comes to diversity of heroes, abilities, and powerful items, Dota boasts an endless array\\u2014no two games are the same. Any hero can fill multiple roles, and there\'s an abundance of items to help meet the needs of each game. Dota doesn\'t provide limitations on how to play, it empowers you to express your own style.<br><br><strong>All heroes are free.</strong><br>Competitive balance is Dota\'s crown jewel, and to ensure everyone is playing on an even field, the core content of the game\\u2014like the vast pool of heroes\\u2014is available to all players. Fans can collect cosmetics for heroes and fun add-ons for the world they inhabit, but everything you need to play is already included before you join your first match.<br><br><strong>Bring your friends and party up.</strong><br>Dota is deep, and constantly evolving, but it\'s never too late to join. <br>Learn the ropes playing co-op vs. bots. Sharpen your skills in the hero demo mode. Jump into the behavior- and skill-based matchmaking system that ensures you\'ll <br>be matched with the right players each game.", "short_description": "Every day, millions of players worldwide enter battle as one of over a hundred Dota heroes. And no matter if it\'s their 10th hour of play or 1,000th, there\'s always something new to discover. With regular updates that ensure a constant evolution of gameplay, features, and heroes, Dota 2 has taken on a life of its own.", "supported_languages": "Bulgarian, Czech, Danish, Dutch, English<strong>*</strong>, Finnish, French, German, Greek, Hungarian, Italian, Japanese, Korean<strong>*</strong>, Norwegian, Polish, Portuguese - Portugal, Portuguese - Brazil, Romanian, Russian, Simplified Chinese<strong>*</strong>, Spanish - Spain, Swedish, Thai, Traditional Chinese, Turkish, Ukrainian, Spanish - Lati ...
#  '{"238960": {"success": true, "data": {"type": "game", "name": "Path of Exile", "steam_appid": 238960, "required_age": 0, "is_free": true, "controller_support": "full", "detailed_description": "You are an Exile, struggling to survive on the dark continent of Wraeclast, as you fight to earn power that will allow you to exact your revenge against those who wronged you. Created by hardcore gamers, Path of Exile is an online Action RPG set in a dark fantasy world. With a focus on visceral action combat, powerful items and deep character customization, Path of Exile is completely free and will never be pay-to-win.<h2 class=\\"bb_tag\\">Key Features</h2><ul class=\\"bb_ul\\"><li><strong>Freedom. Power. Revenge.</strong><br>Banished for your misdeeds to the dark, brutal world of Wraeclast, you play as the Duelist, Witch, Ranger, Templar, Marauder, Shadow or the Scion class. From forsaken shores through to the city of Oriath, explore Wraeclast and uncover the ancient secrets waiting for you.<br></li><li><strong>Unlimited Character Customization</strong><br>Create and customize hundreds of unique skill combinations from tradable itemized gems and our gigantic passive skill tree. Combine skill gems, support gems and trigger gems to create your own unique combination of power, defense and destruction.<br></li><li><strong>Deadly Missions</strong><br>The Masters each have their own style of mission and each of these missions has many variations. As you explore deeper into Wraeclast, the pool of available variations increases to challenge you in new ways. All of the Missions and their variations can occur anywhere in the game, including within end-game Maps.<br></li><li><strong>Dressed to Kill</strong><br>Path of Exile is all about items. Find, collect and trade magic, rare and unique items with arcane properties, then customize your character build around the deadliest combinations you possess.<br></li><li><strong>Brutal Competitive Play</strong><br>Compete in Leagues and Race Events that run as separate game worlds with their own ladders and economies to win valuable prizes.<br></li><li><strong>Customise Your Hideout</strong><br>Once unlocked, you may be taken to a Hideout, where you can create your own personalised town.<br></li><li><strong>Fair-To-Play. Never Pay-To-Win. </strong><br>We\'re committed to creating a fair playing field for all players. You cannot gain gameplay advantage by spending real money in Path of Exile.</li></ul>", "about_the_game": "You are an Exile, struggling to survive on the dark continent of Wraeclast, as you fight to earn power that will allow you to exact your revenge against those who wronged you. Created by hardcore gamers, Path of Exile is an online Action RPG set in a dark fantasy world. With a focus on visceral action combat, powerful items and deep character customization, Path of Exile is completely free and will never be pay-to-win.<h2 class=\\"bb_tag\\">Key Features</h2><ul class=\\"bb_ul\\"><li><strong>Freedom. Power. Revenge.</strong><br>Banished for your misdeeds to the dark, brutal world of Wraeclast, you play as the Duelist, Witch, Ranger, Templar, Marauder, Shadow or the Scion class. From forsaken shores through to the city of Oriath, explore Wraeclast and uncover the ancient secrets waiting for you.<br></li><li><strong>Unlimited Character Customization</strong><br>Create and customize hundreds of unique skill combinations from tradable itemized gems and our gigantic passive skill tree. Combine skill gems, support gems and trigger gems to create your own unique combination of power, defense and destruction.<br></li><li><strong>Deadly Missions</strong><br>The Masters each have their own style of mission and each of these missions has many variations. As you explore deeper into Wraeclast, the pool of available variations increases to challenge you in new ways. All of the Missions and their variations can occur anywhere in the game, including within end-game Maps.<br></li><li><strong>Dressed to  ...
#  '{"730": {"success": true, "data": {"type": "game", "name": "Counter-Strike: Global Offensive", "steam_appid": 730, "required_age": 0, "is_free": true, "controller_support": "full", "detailed_description": "Counter-Strike: Global Offensive (CS: GO) expands upon the team-based action gameplay that it pioneered when it was launched 19 years ago.<br />\\r\\n<br />\\r\\nCS: GO features new maps, characters, weapons, and game modes, and delivers updated versions of the classic CS content (de_dust2, etc.).<br />\\r\\n<br />\\r\\n&quot;Counter-Strike took the gaming industry by surprise when the unlikely MOD became the most played online PC action game in the world almost immediately after its release in August 1999,&quot; said Doug Lombardi at Valve. &quot;For the past 12 years, it has continued to be one of the most-played games in the world, headline competitive gaming tournaments and selling over 25 million units worldwide across the franchise. CS: GO promises to expand on CS\' award-winning gameplay and deliver it to gamers on the PC as well as the next gen consoles and the Mac.&quot;", "about_the_game": "Counter-Strike: Global Offensive (CS: GO) expands upon the team-based action gameplay that it pioneered when it was launched 19 years ago.<br />\\r\\n<br />\\r\\nCS: GO features new maps, characters, weapons, and game modes, and delivers updated versions of the classic CS content (de_dust2, etc.).<br />\\r\\n<br />\\r\\n&quot;Counter-Strike took the gaming industry by surprise when the unlikely MOD became the most played online PC action game in the world almost immediately after its release in August 1999,&quot; said Doug Lombardi at Valve. &quot;For the past 12 years, it has continued to be one of the most-played games in the world, headline competitive gaming tournaments and selling over 25 million units worldwide across the franchise. CS: GO promises to expand on CS\' award-winning gameplay and deliver it to gamers on the PC as well as the next gen consoles and the Mac.&quot;", "short_description": "Counter-Strike: Global Offensive (CS: GO) expands upon the team-based action gameplay that it pioneered when it was launched 19 years ago. CS: GO features new maps, characters, weapons, and game modes, and delivers updated versions of the classic CS content (de_dust2, etc.).", "supported_languages": "Czech, Danish, Dutch, English<strong>*</strong>, Finnish, French, German, Hungarian, Italian, Japanese, Korean, Norwegian, Polish, Portuguese - Portugal, Portuguese - Brazil, Romanian, Russian, Simplified Chinese, Spanish - Spain, Swedish, Thai, Traditional Chinese, Turkish, Bulgarian, Ukrainian, Greek, Spanish - Latin America, Vietnamese<br><strong>*</strong>languages with full audio support", "header_image": "https://cdn.akamai.steamstatic.com/steam/apps/730/header.jpg?t=1683566799", "capsule_image": "https://cdn.akamai.steamstatic.com/steam/apps/730/capsule_231x87.jpg?t=1683566799", "capsule_imagev5": "https://cdn.akamai.steamstatic.com/steam/apps/730/capsule_184x69.jpg?t=1683566799", "website": "http://blog.counter-strike.net/", "pc_requirements": {"minimum": "<strong>Minimum:</strong><br><ul class=\\"bb_ul\\"><li><strong>OS:</strong> Windows\\u00ae 7/Vista/XP<br></li><li><strong>Processor:</strong> Intel\\u00ae Core\\u2122 2 Duo E6600 or AMD Phenom\\u2122 X3 8750 processor or better<br></li><li><strong>Memory:</strong> 2 GB RAM<br></li><li><strong>Graphics:</strong> Video card must be 256 MB or more and should be a DirectX 9-compatible with support for Pixel Shader 3.0<br></li><li><strong>DirectX:</strong> Version 9.0c<br></li><li><strong>Storage:</strong> 15 GB available space</li></ul>"}, "mac_requirements": {"minimum": "<strong>Minimum:</strong><br><ul class=\\"bb_ul\\"><li><strong>OS:</strong> MacOS X 10.11 (El Capitan) or later<br></li><li><strong>Processor:</strong> Intel Core Duo Processor (2GHz or better)<br></li><li><strong>Memory:</strong> 2 GB RAM<br></li><li><strong>Graphics:</strong> ATI Radeon HD 2400 or better / ...
#  '{"393420": {"success": true, "data": {"type": "game", "name": "Hurtworld", "steam_appid": 393420, "required_age": 0, "is_free": false, "detailed_description": "Hurtworld is a hardcore multiplayer survival FPS with a focus on competitive gunplay and strategic map control. It was a super raw experience when we launched into early access three years ago but with the help of the community we have refined and ironed out the majority of issues to a point where we are happy to start expanding our player base.<br><br>Brave the elements with friends or alone as you gather the necessities to survive, grow and defend your place amongst Hurtworld\\u2019s unforgiving environment. Populated by fierce creatures, rich resources and ever evolving challenges, Hurtworld is an immersive multiplayer experience sure to captivate even the most seasoned gamer.<br><br>Craft tools, weapons and clothing to help you survive and defend what\\u2019s yours.<br>Construct a stronghold to stash loot and take refuge in. <br>Find and restore vehicles abandoned throughout the map.<br>Explore the many biomes to discover exotic resources and rare items.\\t<br><br>Built from the ground up with solid multiplayer foundations designed for fast skill based PVP and PVE. Hurtworld is extremely optimised with highly scalable graphics to perform well on the most budget of machines.<br><br>Get involved in our Discord @ <a href=\\"https://steamcommunity.com/linkfilter/?url=http://discord.hurtworld.com\\" target=\\"_blank\\" rel=\\" noopener\\"  >http://discord.hurtworld.com</a>", "about_the_game": "Hurtworld is a hardcore multiplayer survival FPS with a focus on competitive gunplay and strategic map control. It was a super raw experience when we launched into early access three years ago but with the help of the community we have refined and ironed out the majority of issues to a point where we are happy to start expanding our player base.<br><br>Brave the elements with friends or alone as you gather the necessities to survive, grow and defend your place amongst Hurtworld\\u2019s unforgiving environment. Populated by fierce creatures, rich resources and ever evolving challenges, Hurtworld is an immersive multiplayer experience sure to captivate even the most seasoned gamer.<br><br>Craft tools, weapons and clothing to help you survive and defend what\\u2019s yours.<br>Construct a stronghold to stash loot and take refuge in. <br>Find and restore vehicles abandoned throughout the map.<br>Explore the many biomes to discover exotic resources and rare items.\\t<br><br>Built from the ground up with solid multiplayer foundations designed for fast skill based PVP and PVE. Hurtworld is extremely optimised with highly scalable graphics to perform well on the most budget of machines.<br><br>Get involved in our Discord @ <a href=\\"https://steamcommunity.com/linkfilter/?url=http://discord.hurtworld.com\\" target=\\"_blank\\" rel=\\" noopener\\"  >http://discord.hurtworld.com</a>", "short_description": "Hurtworld is a hardcore multiplayer survival FPS with a focus on competitive gunplay and strategic map control. Built for hardcore gamers, Hurtworld aims to punish.", "supported_languages": "English, French, Italian, German, Spanish - Spain, Russian, Turkish, Ukrainian, Czech, Dutch, Polish, Portuguese - Brazil, Swedish, Japanese, Simplified Chinese", "header_image": "https://cdn.akamai.steamstatic.com/steam/apps/393420/header.jpg?t=1597169414", "capsule_image": "https://cdn.akamai.steamstatic.com/steam/apps/393420/capsule_231x87.jpg?t=1597169414", "capsule_imagev5": "https://cdn.akamai.steamstatic.com/steam/apps/393420/capsule_184x69.jpg?t=1597169414", "website": "http://www.hurtworld.com", "pc_requirements": {"minimum": "<strong>Minimum:</strong><br><ul class=\\"bb_ul\\"><li>Requires a 64-bit processor and operating system<br></li><li><strong>OS:</strong> Windows XP 64<br></li><li><strong>Processor:</strong> 2 GHz<br></li><li><strong>Memory:</strong> 4 GB RAM<br></li><li><strong>Graphic ...
#  '{"1245620": {"success": true, "data": {"type": "game", "name": "ELDEN RING", "steam_appid": 1245620, "required_age": 0, "is_free": false, "controller_support": "full", "detailed_description": "<h1>More games by From Software</h1><p><a href=\\"https://store.steampowered.com/app/1888160/ARMORED_CORE_VI_FIRES_OF_RUBICON/\\" target=\\"_blank\\" rel=\\"\\"  id=\\"dynamiclink_0\\" >https://store.steampowered.com/app/1888160/ARMORED_CORE_VI_FIRES_OF_RUBICON/</a><br><a href=\\"https://store.steampowered.com/app/814380/Sekiro_Shadows_Die_Twice__GOTY_Edition/\\" target=\\"_blank\\" rel=\\"\\"  id=\\"dynamiclink_1\\" >https://store.steampowered.com/app/814380/Sekiro_Shadows_Die_Twice__GOTY_Edition/</a></p><br><h1>More games by From Software</h1><p><a href=\\"https://store.steampowered.com/app/374320/DARK_SOULS_III/\\" target=\\"_blank\\" rel=\\"\\"  id=\\"dynamiclink_2\\" >https://store.steampowered.com/app/374320/DARK_SOULS_III/</a><br><a href=\\"https://store.steampowered.com/app/335300/DARK_SOULS_II_Scholar_of_the_First_Sin/\\" target=\\"_blank\\" rel=\\"\\"  >https://store.steampowered.com/app/335300/DARK_SOULS_II_Scholar_of_the_First_Sin/</a><br><a href=\\"https://store.steampowered.com/app/570940/DARK_SOULS_REMASTERED/\\" target=\\"_blank\\" rel=\\"\\"  >https://store.steampowered.com/app/570940/DARK_SOULS_REMASTERED/</a></p><br><h1>ELDEN RING Deluxe Edition</h1><p><img src=\\"https://cdn.akamai.steamstatic.com/steam/apps/1245620/extras/ER_Deluxe_Beautyshot_GIF_EN.gif?t=1683618443\\" /><br>The Deluxe Edition includes:<br>\\u2022 ELDEN RING (full game)<br>\\u2022 Digital Artbook &amp; Original Soundtrack</p><br><h1>About the Game</h1><img src=\\"https://cdn.akamai.steamstatic.com/steam/apps/1245620/extras/ER_Steam_Gif_616x260.gif?t=1683618443\\" /><br><br>THE NEW FANTASY ACTION RPG.<br>Rise, Tarnished, and be guided by grace to brandish the power of the Elden Ring and become an Elden Lord in the Lands Between.<h2 class=\\"bb_tag\\">\\u2022 A Vast World Full of Excitement</h2>A vast world where open fields with a variety of situations and huge dungeons with complex and three-dimensional designs are seamlessly connected. As you explore, the joy of discovering unknown and overwhelming threats await you, leading to a high sense of accomplishment.<h2 class=\\"bb_tag\\">\\u2022 Create your Own Character</h2>In addition to customizing the appearance of your character, you can freely combine the weapons, armor, and magic that you equip. You can develop your character according to your play style, such as increasing your muscle strength to become a strong warrior, or mastering magic.<h2 class=\\"bb_tag\\">\\u2022 An Epic Drama Born from a Myth</h2>A multilayered story told in fragments. An epic drama in which the various thoughts of the characters intersect in the Lands Between.<h2 class=\\"bb_tag\\">\\u2022 Unique Online Play that Loosely Connects You to Others</h2>In addition to multiplayer, where you can directly connect with other players and travel together, the game supports a unique asynchronous online element that allows you to feel the presence of others.", "about_the_game": "<img src=\\"https://cdn.akamai.steamstatic.com/steam/apps/1245620/extras/ER_Steam_Gif_616x260.gif?t=1683618443\\" /><br><br>THE NEW FANTASY ACTION RPG.<br>Rise, Tarnished, and be guided by grace to brandish the power of the Elden Ring and become an Elden Lord in the Lands Between.<h2 class=\\"bb_tag\\">\\u2022 A Vast World Full of Excitement</h2>A vast world where open fields with a variety of situations and huge dungeons with complex and three-dimensional designs are seamlessly connected. As you explore, the joy of discovering unknown and overwhelming threats await you, leading to a high sense of accomplishment.<h2 class=\\"bb_tag\\">\\u2022 Create your Own Character</h2>In addition to customizing the appearance of your character, you can freely combine the weapons, armor, and magic that you equip. You can develop your character according to your play style, ...
#  '{"526870": {"success": true, "data": {"type": "game", "name": "Satisfactory", "steam_appid": 526870, "required_age": 0, "is_free": false, "detailed_description": "<h1>Join our Discord</h1><p><a href=\\"https://steamcommunity.com/linkfilter/?url=https://discord.gg/satisfactory\\" target=\\"_blank\\" rel=\\" noopener\\"  ><img src=\\"https://cdn.akamai.steamstatic.com/steam/apps/526870/extras/Discord_02.jpg?t=1670335305\\" /></a></p><br><h1>About the Game</h1>Satisfactory is a first-person open-world factory building game with a dash of exploration and combat. Play alone or with friends, explore an alien planet, create multi-story factories, and enter conveyor belt heaven!<h2 class=\\"bb_tag\\">Construct</h2>Conquer nature by building massive factories across the land. Expand wherever and however you want. The planet is filled with valuable natural resources just waiting to be utilized. As an employee of FICSIT it\\u2019s your duty to make sure they come to good use.<h2 class=\\"bb_tag\\">Automate</h2>Construct your factories with gracious perfection or build intricate webs of conveyor belts to supply all your needs. Automate trucks and trains to reach your faraway outposts and be sure to handle liquids properly by transporting them in pipes. It\\u2019s all about minimizing manual labour!<h2 class=\\"bb_tag\\">Explore &amp; Exploit</h2>Venture on expeditions to search for new materials and be sure to put everything to good use. Nature is yours to harvest! You have vehicles, jetpacks, jump pads and more at your disposal to make the exploration easier. Equip the proper safety gear as well, just in case you run into the local wildlife.<h2 class=\\"bb_tag\\">FEATURES</h2>\\u2022\\t<strong>Open World: </strong>Explore the huge (30km2) alien planet that is Massage-2(AB)b with its unique fauna and creatures.<br>\\u2022\\t<strong>Co-Op:</strong> Build a factory yourself or share the joy with your friends. Up to you!<br>\\u2022\\t<strong>Factory Building:</strong> Experience building a huge factory from a first-person perspective. Automate and optimize it to perfection for your personal satisfaction.<br>\\u2022\\t<strong>Customization:</strong> Customize your factory to your own liking. Build at high altitudes or over wide plains, there is almost no limits in the making of your tailor-made factory. <br>\\u2022\\t<strong>Vehicles:</strong> Travel the world with class. Use jump pads, factory carts, jetpacks, hypertubes, trucks or trains. The choice is yours!", "about_the_game": "Satisfactory is a first-person open-world factory building game with a dash of exploration and combat. Play alone or with friends, explore an alien planet, create multi-story factories, and enter conveyor belt heaven!<h2 class=\\"bb_tag\\">Construct</h2>Conquer nature by building massive factories across the land. Expand wherever and however you want. The planet is filled with valuable natural resources just waiting to be utilized. As an employee of FICSIT it\\u2019s your duty to make sure they come to good use.<h2 class=\\"bb_tag\\">Automate</h2>Construct your factories with gracious perfection or build intricate webs of conveyor belts to supply all your needs. Automate trucks and trains to reach your faraway outposts and be sure to handle liquids properly by transporting them in pipes. It\\u2019s all about minimizing manual labour!<h2 class=\\"bb_tag\\">Explore &amp; Exploit</h2>Venture on expeditions to search for new materials and be sure to put everything to good use. Nature is yours to harvest! You have vehicles, jetpacks, jump pads and more at your disposal to make the exploration easier. Equip the proper safety gear as well, just in case you run into the local wildlife.<h2 class=\\"bb_tag\\">FEATURES</h2>\\u2022\\t<strong>Open World: </strong>Explore the huge (30km2) alien planet that is Massage-2(AB)b with its unique fauna and creatures.<br>\\u2022\\t<strong>Co-Op:</strong> Build a factory yourself or share the joy with your friends. Up to you!<br>\\u202 ...
#  '{"435150": {"success": true, "data": {"type": "game", "name": "Divinity: Original Sin 2 - Definitive Edition", "steam_appid": 435150, "required_age": 0, "is_free": false, "controller_support": "full", "dlc": [715950, 880640, 1247270], "detailed_description": "<h1>Digital Collector\'s Editions</h1><p><img src=\\"https://cdn.akamai.steamstatic.com/steam/apps/435150/extras/Divine-Edition-v7.png?t=1668591196\\" /><br><br><img src=\\"https://cdn.akamai.steamstatic.com/steam/apps/435150/extras/Eternal-Edition-v7.png?t=1668591196\\" /></p><br><h1>About the Game</h1><img src=\\"https://cdn.akamai.steamstatic.com/steam/apps/435150/extras/Steam-Info-Banner.jpg?t=1668591196\\" /><br><br>The Divine is dead. The Void approaches. And the powers lying dormant within you are soon to awaken. The battle for Divinity has begun. Choose wisely and trust sparingly; darkness lurks within every heart.<br> <br><img src=\\"https://cdn.akamai.steamstatic.com/steam/apps/435150/extras/SteamGif-GyP.png?t=1668591196\\" /><h2 class=\\"bb_tag\\">Who will you be?</h2> A flesh-eating Elf, an Imperial Lizard or an Undead, risen from the grave? Discover how the world reacts differently to who - or what - you are.<h2 class=\\"bb_tag\\">It\\u2019s time for a new Divinity!</h2>  <br>Gather your party and develop relationships with your companions. Blast your opponents in deep, tactical, turn-based combat. Use the environment as a weapon, use height to your advantage, and manipulate the elements themselves to seal your victory.<h2 class=\\"bb_tag\\">Ascend as the god that Rivellon so desperately needs.</h2><br>Explore the vast and layered world of Rivellon alone or in a party of up to 4 players in drop-in/drop-out cooperative play. Go anywhere, unleash your imagination, and explore endless ways to interact with the world. Beyond Rivellon, there\\u2019s more to explore in the brand-new PvP and Game Master modes.<br><br><img src=\\"https://cdn.akamai.steamstatic.com/steam/apps/435150/extras/SteamGif-BecomeDivine.png?t=1668591196\\" /><br><br><ul class=\\"bb_ul\\"><li><strong>Choose your race and origin.</strong> Choose from 6 unique origin characters with their own backgrounds and quests, or create your own as a Human, Lizard, Elf, Dwarf, or Undead. All choices have consequences.<br><br></li><li><strong>Unlimited freedom to explore and experiment</strong>. Go anywhere, talk to anyone, and interact with everything! Kill any NPC without sacrificing your progress, and speak to every animal. Even ghosts might be hiding a secret or two\\u2026<br><br></li><li><strong>The next generation of turn-based combat.</strong> Blast your opponents with elemental combinations. Use height to your advantage. Master over 200 skills in 12 skill schools. But beware - the game\\u2019s AI 2.0 is our most devious invention to date.<br><br></li><li><strong>Up to 4 player online and split-screen multiplayer.</strong> Play with your friends online or in local split-screen with full controller support.<br><br></li><li><strong>Game Master Mode:</strong> Take your adventures to the next level and craft your own stories with the Game Master Mode. Download fan-made campaigns and mods from Steam Workshop.<br><br></li><li><strong>4K Support:</strong> an Ultimate 4K experience pushing RPGs into a new era!<br><br><a href=\\"https://steamcommunity.com/linkfilter/?url=https://www.nvidia.com/en-us/geforce/products/10series/ultimate-4k/\\" target=\\"_blank\\" rel=\\" noopener\\"  ><img src=\\"https://cdn.akamai.steamstatic.com/steam/apps/435150/extras/4K_ULTIMATE_Logo_vert_BLKBGRD_V2_150.png?t=1668591196\\" /></a></li></ul>", "about_the_game": "<img src=\\"https://cdn.akamai.steamstatic.com/steam/apps/435150/extras/Steam-Info-Banner.jpg?t=1668591196\\" /><br><br>The Divine is dead. The Void approaches. And the powers lying dormant within you are soon to awaken. The battle for Divinity has begun. Choose wisely and trust sparingly; darkness lurks within every heart.<br> <br><img src=\\"https://cdn.akamai.stea ...
#  '{"440": {"success": true, "data": {"type": "game", "name": "Team Fortress 2", "steam_appid": 440, "required_age": 0, "is_free": true, "dlc": [629330], "detailed_description": "<p><strong>\\"The most fun you can have online\\"</strong> - PC Gamer<br>\\r\\n\\t\\t\\t\\t\\t\\t\\t\\t\\t <strong>Is now FREE!</strong><br>\\r\\n\\t\\t\\t\\t\\t\\t\\t\\t\\t There\\u2019s no catch! Play as much as you want, as long as you like!</p>\\r\\n\\t\\t\\t\\t\\t\\t\\t\\t\\t <p><strong>The most highly-rated free game of all time!</strong><br>\\r\\n\\t\\t\\t\\t\\t\\t\\t\\t\\t One of the most popular online action games of all time, Team Fortress 2 delivers constant free updates\\u2014new game modes, maps, equipment and, most importantly, hats. Nine distinct classes provide a broad range of tactical abilities and personalities, and lend themselves to a variety of player skills.</p>\\r\\n\\t\\t\\t\\t\\t\\t\\t\\t\\t <p><strong>New to TF? Don\\u2019t sweat it!</strong><br>\\r\\n\\t\\t\\t\\t\\t\\t\\t\\t\\t No matter what your style and experience, we\\u2019ve got a character for you. Detailed training and offline practice modes will help you hone your skills before jumping into one of TF2\\u2019s many game modes, including Capture the Flag, Control Point, Payload, Arena, King of the Hill and more.</p>\\r\\n\\t\\t\\t\\t\\t\\t\\t\\t\\t <p><strong>Make a character your own!</strong><br>\\r\\n\\t\\t\\t\\t\\t\\t\\t\\t\\t There are hundreds of weapons, hats and more to collect, craft, buy and trade. Tweak your favorite class to suit your gameplay style and personal taste. You don\\u2019t need to pay to win\\u2014virtually all of the items in the Mann Co. Store can also be found in-game.</p>\\r\\n\\t\\t\\t\\t\\t\\t\\t\\t\\t<a href=\\"http://www.teamfortress.com/freetoplay\\"><img src=\\"http://storefront.steampowered.com/v/gfx/apps/440/extras/page_banner_english1.jpg\\"></a>\\r\\n\\t\\t\\t\\t\\t\\t\\t\\t\\t", "about_the_game": "<p><strong>\\"The most fun you can have online\\"</strong> - PC Gamer<br>\\r\\n\\t\\t\\t\\t\\t\\t\\t\\t\\t <strong>Is now FREE!</strong><br>\\r\\n\\t\\t\\t\\t\\t\\t\\t\\t\\t There\\u2019s no catch! Play as much as you want, as long as you like!</p>\\r\\n\\t\\t\\t\\t\\t\\t\\t\\t\\t <p><strong>The most highly-rated free game of all time!</strong><br>\\r\\n\\t\\t\\t\\t\\t\\t\\t\\t\\t One of the most popular online action games of all time, Team Fortress 2 delivers constant free updates\\u2014new game modes, maps, equipment and, most importantly, hats. Nine distinct classes provide a broad range of tactical abilities and personalities, and lend themselves to a variety of player skills.</p>\\r\\n\\t\\t\\t\\t\\t\\t\\t\\t\\t <p><strong>New to TF? Don\\u2019t sweat it!</strong><br>\\r\\n\\t\\t\\t\\t\\t\\t\\t\\t\\t No matter what your style and experience, we\\u2019ve got a character for you. Detailed training and offline practice modes will help you hone your skills before jumping into one of TF2\\u2019s many game modes, including Capture the Flag, Control Point, Payload, Arena, King of the Hill and more.</p>\\r\\n\\t\\t\\t\\t\\t\\t\\t\\t\\t <p><strong>Make a character your own!</strong><br>\\r\\n\\t\\t\\t\\t\\t\\t\\t\\t\\t There are hundreds of weapons, hats and more to collect, craft, buy and trade. Tweak your favorite class to suit your gameplay style and personal taste. You don\\u2019t need to pay to win\\u2014virtually all of the items in the Mann Co. Store can also be found in-game.</p>\\r\\n\\t\\t\\t\\t\\t\\t\\t\\t\\t<a href=\\"http://www.teamfortress.com/freetoplay\\"><img src=\\"http://storefront.steampowered.com/v/gfx/apps/440/extras/page_banner_english1.jpg\\"></a>\\r\\n\\t\\t\\t\\t\\t\\t\\t\\t\\t", "short_description": "Nine distinct classes provide a broad range of tactical abilities and personalities. Constantly updated with new game modes, maps, equipment and, most importantly, hats!", "supported_languages": "English<strong>*</strong>, Danish, Dutch, Finnish, French, German, Italian, Japanese, Norwegian, Polish, Portuguese - Por ...
#  '{"252950": {"success": true, "data": {"type": "game", "name": "Rocket League\\u00ae", "steam_appid": 252950, "required_age": 0, "is_free": false, "controller_support": "full", "detailed_description": "Rocket League is a high-powered hybrid of arcade-style soccer and vehicular mayhem with easy-to-understand controls and fluid, physics-driven competition. Rocket League includes casual and competitive Online Matches, a fully-featured offline Season Mode, special \\u201cMutators\\u201d that let you change the rules entirely, hockey and basketball-inspired Extra Modes, and more than 500 trillion possible cosmetic customization combinations.<br><br>Winner or nominee of more than 150 \\u201cGame of the Year\\u201d awards, Rocket League is one of the most critically-acclaimed sports games of all time. Boasting a community of more than 57 million players, Rocket League features ongoing free and paid updates, including new DLCs, content packs, features, modes and arenas.<br><br><strong>What\'s New:</strong><br><ul class=\\"bb_ul\\"><li>Rocket Pass - Purchase Rocket Pass Premium to get an initial 50% XP bonus and earn up to 70 unique rewards, including a new Battle-Car, Goal Explosion, Keys, and more!<br></li><li>Challenge System - Play Online Matches and complete Weekly Challenges to tier up and unlock unique rewards only found in Rocket Pass.<br></li><li>Esports Shop - Show off your team pride for your favorite teams in Rocket League Esports! The Rocket League Esports Shop pilot program brings new Decals, Wheels, and Player Banners that represent some of the best teams in the sport. of the best teams in the sport. <br><br><strong>SteamOS and Mac Beta Versions</strong><br>As we continue to upgrade <strong>Rocket League\\u00ae</strong> with new technologies like DirectX 11 and a 64-bit client, it is no longer viable for us to maintain support for the macOS and Linux (SteamOS) platforms. As a result, the final patch for the macOS and Linux versions of Rocket League was released on March 10, 2020. This update disabled online functionality (such as Casual and Competitive Playlists) for players on macOS and Linux, but offline features including Local Matches, and splitscreen play are still accessible.<br><br>Please note that Rocket League\\u00ae on SteamOS and macOS may have bugs and stability issues not seen in the Windows version of the game, and these issues may not be fixed in future updates.<br><br><i>NOTE: Because of agreements with our online service provider, there are certain regions that are unable to connect to Rocket League\\u00ae\\u2019s online multiplayer component. As a result, server access is restricted in China, Crimea, Cuba, Iran, North Korea, Sudan, and Syria. Apologies to our customers in those regions.</i><br><br>Software and online features are subject to license, terms of use, and privacy policy ( <a href=\\"https://steamcommunity.com/linkfilter/?url=http://rocketleague.com/eula\\" target=\\"_blank\\" rel=\\" noopener\\"  >rocketleague.com/eula</a> , <a href=\\"https://steamcommunity.com/linkfilter/?url=http://rocketleague.com/tou\\" target=\\"_blank\\" rel=\\" noopener\\"  >rocketleague.com/tou</a> ,  and <a href=\\"https://steamcommunity.com/linkfilter/?url=http://rocketleague.com/privacy\\" target=\\"_blank\\" rel=\\" noopener\\"  >rocketleague.com/privacy</a> ).</li></ul>", "about_the_game": "Rocket League is a high-powered hybrid of arcade-style soccer and vehicular mayhem with easy-to-understand controls and fluid, physics-driven competition. Rocket League includes casual and competitive Online Matches, a fully-featured offline Season Mode, special \\u201cMutators\\u201d that let you change the rules entirely, hockey and basketball-inspired Extra Modes, and more than 500 trillion possible cosmetic customization combinations.<br><br>Winner or nominee of more than 150 \\u201cGame of the Year\\u201d awards, Rocket League is one of the most critically-acclaimed sports games of all time. Boasting a community of mor ...
#  '{"1604030": {"success": true, "data": {"type": "game", "name": "V Rising", "steam_appid": 1604030, "required_age": 0, "is_free": false, "dlc": [1983900, 1983901, 1999270, 2358430], "detailed_description": "<strong>A Vampire Survival Experience</strong><br><br>Awaken as a weakened vampire after centuries of slumber. Hunt for blood to regain your strength while hiding from the scorching sun to survive. Rebuild your castle and convert humans into your loyal servants in a quest to raise your vampire empire. Make allies or enemies online or play solo locally, fend off holy soldiers, and wage war in a world of conflict. <br><br>Will you become the next Dracula?<h2 class=\\"bb_tag\\">A Gothic Open-World </h2><br>Explore a vast world teeming with mythical horrors and danger. Travel through lush forests, open countryside, and dark caverns to discover valuable resources, meeting friends and foes alike along the way. Traverse the world with vampire comrades or hunt solo as you pillage villages, raid bandits, and delve into the domains of supernatural beasts.<br><br><img src=\\"https://cdn.akamai.steamstatic.com/steam/apps/1604030/extras/OpenWorld01_1.gif?t=1684394834\\" /><h2 class=\\"bb_tag\\">Fear the light - Rule the night </h2><br>Stick to the shadows during the daytime, or the burning sunlight will turn you to ashes. Roam the night and prey on your victims in the darkness. As a vampire, you must quench your thirst for blood while planning your strategies around the day and nighttime.<br><br><img src=\\"https://cdn.akamai.steamstatic.com/steam/apps/1604030/extras/FearTheLightRuleTheNight_1__1_.gif?t=1684394834\\" /><h2 class=\\"bb_tag\\">Raise your Castle</h2> <br>Gather resources and discover ancient techniques to gain dark powers. Use your newly acquired knowledge to build a castle where you can store your loot and grow your army of darkness. Personalize your domain, exhibit your vampiric style and make sure to craft coffins for servants and friends. Strengthen your castle to protect your treasure hoard from vampire rivals.<br><br><img src=\\"https://cdn.akamai.steamstatic.com/steam/apps/1604030/extras/RaiseYourCastle_1.gif?t=1684394834\\" /><h2 class=\\"bb_tag\\">Compete or Cooperate </h2><br>Travel alone or explore the world with friends. Fighting side by side with other vampires will give you an advantage in the fight to conquer the greatest threats of Vardoran. Raid other players\\u2019 castles or play the diplomat in the game of blood, power, and betrayal. Compete or cooperate - the choice is yours.<br><br><img src=\\"https://cdn.akamai.steamstatic.com/steam/apps/1604030/extras/CompeteOrCooperate_3.gif?t=1684394834\\" /><h2 class=\\"bb_tag\\">Master your Vampire</h2><br>Learn and master an arsenal of deadly weapons and unholy abilities. In V Rising, you aim skill-shots and dodge projectiles using\\u200b precise\\u200b\\u200b \\u200bWASD controls \\u200band cursor-based\\u200b \\u200baiming - no click to move. Tailor your vampire to fit your play style by combining weapons with a variety of spells earned through vanquishing powerful foes. Master your skills and unleash your wicked powers.<br><br><img src=\\"https://cdn.akamai.steamstatic.com/steam/apps/1604030/extras/MasterYourVampire_1.gif?t=1684394834\\" />", "about_the_game": "<strong>A Vampire Survival Experience</strong><br><br>Awaken as a weakened vampire after centuries of slumber. Hunt for blood to regain your strength while hiding from the scorching sun to survive. Rebuild your castle and convert humans into your loyal servants in a quest to raise your vampire empire. Make allies or enemies online or play solo locally, fend off holy soldiers, and wage war in a world of conflict. <br><br>Will you become the next Dracula?<h2 class=\\"bb_tag\\">A Gothic Open-World </h2><br>Explore a vast world teeming with mythical horrors and danger. Travel through lush forests, open countryside, and dark caverns to discover valuable resources, meeting friends and foes alike along the  ...

# %%
pprint.pprint(type(apps_data))
apps_data
# Out:
# <class 'dict'>
# {570: {'570': {'success': True,
#    'data': {'type': 'game',
#     'name': 'Dota 2',
#     'steam_appid': 570,
#     'required_age': 0,
#     'is_free': True,
#     'dlc': [1241930, 652720],
#     'detailed_description': "<strong>The most-played game on Steam.</strong><br>Every day, millions of players worldwide enter battle as one of over a hundred Dota heroes. And no matter if it's their 10th hour of play or 1,000th, there's always something new to discover. With regular updates that ensure a constant evolution of gameplay, features, and heroes, Dota 2 has truly taken on a life of its own.<br><br><strong>One Battlefield. Infinite Possibilities.</strong><br>When it comes to diversity of heroes, abilities, and powerful items, Dota boasts an endless array—no two games are the same. Any hero can fill multiple roles, and there's an abundance of items to help meet the needs of each game. Dota doesn't provide limitations on how to play, it empowers you to express your own style.<br><br><strong>All heroes are free.</strong><br>Competitive balance is Dota's crown jewel, and to ensure everyone is playing on an even field, the core content of the game—like the vast pool of heroes—is available to all players. Fans can collect cosmetics for heroes and fun add-ons for the world they inhabit, but everything you need to play is already included before you join your first match.<br><br><strong>Bring your friends and party up.</strong><br>Dota is deep, and constantly evolving, but it's never too late to join. <br>Learn the ropes playing co-op vs. bots. Sharpen your skills in the hero demo mode. Jump into the behavior- and skill-based matchmaking system that ensures you'll <br>be matched with the right players each game.",
#     'about_the_game': "<strong>The most-played game on Steam.</strong><br>Every day, millions of players worldwide enter battle as one of over a hundred Dota heroes. And no matter if it's their 10th hour of play or 1,000th, there's always something new to discover. With regular updates that ensure a constant evolution of gameplay, features, and heroes, Dota 2 has truly taken on a life of its own.<br><br><strong>One Battlefield. Infinite Possibilities.</strong><br>When it comes to diversity of heroes, abilities, and powerful items, Dota boasts an endless array—no two games are the same. Any hero can fill multiple roles, and there's an abundance of items to help meet the needs of each game. Dota doesn't provide limitations on how to play, it empowers you to express your own style.<br><br><strong>All heroes are free.</strong><br>Competitive balance is Dota's crown jewel, and to ensure everyone is playing on an even field, the core content of the game—like the vast pool of heroes—is available to all players. Fans can collect cosmetics for heroes and fun add-ons for the world they inhabit, but everything you need to play is already included before you join your first match.<br><br><strong>Bring your friends and party up.</strong><br>Dota is deep, and constantly evolving, but it's never too late to join. <br>Learn the ropes playing co-op vs. bots. Sharpen your skills in the hero demo mode. Jump into the behavior- and skill-based matchmaking system that ensures you'll <br>be matched with the right players each game.",
#     'short_description': "Every day, millions of players worldwide enter battle as one of over a hundred Dota heroes. And no matter if it's their 10th hour of play or 1,000th, there's always something new to discover. With regular updates that ensure a constant evolution of gameplay, features, and heroes, Dota 2 has taken on a life of its own.",
#     'supported_languages': 'Bulgarian, Czech, Danish, Dutch, English<strong>*</strong>, Finnish, French, German, Greek, Hungarian, Italian, Japanese, Korean<strong>*</strong>, Norwegian, Polish, Portuguese - Portugal, Portuguese - Brazil, Romanian, Russian, Simplified Chinese<strong>*</strong>, Spanish - Spain, Swedish, Thai, Traditional Chinese, Turkish, Ukrainian, Spanish - Latin America, Vietnamese<br><strong>*</strong>languages with full audio support',
#     'reviews': '“A modern multiplayer masterpiece.”<br>9.5/10 – <a href="https://www.destructoid.com/review-dota-2-258506.phtml" target="_blank" rel=""  >Destructoid</a><br><br>“Once you start to learn its secrets, there’s a wild and exciting variety of play here that’s unmatched, even by its peers.”<br>9.4/10 – <a href="http://www.ign.com/articles/2013/07/24/dota-2-review" target="_blank" rel=""  >IGN</a><br><br>“Dota 2 is possibly the only competitive free-to-play game that is totally uncompromised by its business model.”<br>90/100 – <a href="http://www.pcgamer.com/dota-2-review-2/" target="_blank" rel=""  >PC Gamer</a><br>',
#     'header_image': 'https://cdn.akamai.steamstatic.com/steam/apps/570/header.jpg?t=1682639497',
#     'capsule_image': 'https://cdn.akamai.steamstatic.com/steam/apps/570/capsule_231x87.jpg?t=1682639497',
#     'capsule_imagev5': 'https://cdn.akamai.steamstatic.com/steam/apps/570/capsule_184x69.jpg?t=1682639497',
#     'website': 'http://www.dota2.com/',
#     'pc_requirements': {'minimum': '<strong>Minimum:</strong><br><ul class="bb_ul"><li><strong>OS:</strong> Windows 7 or newer<br></li><li><strong>Processor:</strong> Dual core from Intel or AMD at 2.8 GHz<br></li><li><strong>Memory:</strong> 4 GB RAM<br></li><li><strong>Graphics:</strong> NVIDIA GeForce 8600/9600GT, ATI/AMD Radeon HD2600/3600<br></li><li><strong>DirectX:</strong> Version 11<br></li><li><strong>Network:</strong> Broadband Internet connection<br></li><li><strong>Storage:</strong> 60 GB available space<br></li><li><strong>Sound Card:</strong> DirectX Compatible</li></ul>'},
#     'mac_requirements': {'minimum': '<strong>Minimum:</strong><br><ul class="bb_ul"><li><strong>OS:</strong> macOS 10.13.6 or newer<br></li><li><strong>Processor:</strong> Dual core from Intel<br></li><li><strong>Memory:</strong> 4 GB RAM<br></li><li><strong>Graphics:</strong> Metal-capable GPU (AMD GCN-based GPU or newer, NVIDIA Kepler-based GPU or newer, Intel HD 4000 or newer)<br></li><li><strong>Network:</strong> Broadband Internet connection<br></li><li><strong>Storage:</strong> 60 GB available space</li></ul>'},
#     'linux_requirements': {'minimum': '<strong>Minimum:</strong><br><ul class="bb_ul"><li><strong>OS:</strong> Ubuntu 12.04 or newer<br></li><li><strong>Processor:</strong> Dual core from Intel or AMD at 2.8 GHz<br></li><li><strong>Memory:</strong> 4 GB RAM<br></li><li><strong>Graphics:</strong> AMD GCN+, NVIDIA Kepler+, or Intel HD 5000-series or newer<br></li><li><strong>Network:</strong> Broadband Internet connection<br></li><li><strong>Storage:</strong> 60 GB available space<br></li><li><strong>Sound Card:</strong> OpenAL Compatible Sound Card</li></ul>'},
#     'developers': ['Valve'],
#     'publishers': ['Valve'],
#     'packages': [49307, 197846, 330209],
#     'package_groups': [{'name': 'default',
#       'title': 'Buy Dota 2',
#       'description': '',
#       'selection_text': 'Select a purchase option',
#       'save_text': '',
#       'display_type': 0,
#       'is_recurring_subscription': 'false',
#       'subs': [{'packageid': 197846,
#         'percent_savings_text': ' ',
#         'percent_savings': 0,
#         'option_text': 'Dota 2 - Commercial License - Free',
#         'option_description': '',
#         'can_get_free_license': '0',
#         'is_free_license': True,
#         'price_in_cents_with_discount': 0}]}],
#     'platforms': {'windows': True, 'mac': True, 'linux': True},
#     'metacritic': {'score': 90,
#      'url': 'https://www.metacritic.com/game/pc/dota-2?ftag=MCD-06-10aaa1f'},
#     'categories': [{'id': 1, 'description': 'Multi-player'},
#      {'id': 9, 'description': 'Co-op'},
#      {'id': 29, 'description': 'Steam Trading Cards'},
#      {'id': 30, 'description': 'Steam Workshop'},
#      {'id': 40, 'description': 'SteamVR Collectibles'},
#      {'id': 35, 'description': 'In-App Purchases'},
#      {'id': 8, 'description': 'Valve Anti-Cheat enabled'}],
#     'genres': [{'id': '1', 'description': 'Action'},
#      {'id': '37', 'description': 'Free to Play'},
#      {'id': '2', 'description': 'Strategy'}],
#     'screenshots': [{'id': 0,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/570/ss_ad8eee787704745ccdecdfde3a5cd2733704898d.600x338.jpg?t=1682639497',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/570/ss_ad8eee787704745ccdecdfde3a5cd2733704898d.1920x1080.jpg?t=1682639497'},
#      {'id': 1,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/570/ss_7ab506679d42bfc0c0e40639887176494e0466d9.600x338.jpg?t=1682639497',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/570/ss_7ab506679d42bfc0c0e40639887176494e0466d9.1920x1080.jpg?t=1682639497'},
#      {'id': 2,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/570/ss_c9118375a2400278590f29a3537769c986ef6e39.600x338.jpg?t=1682639497',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/570/ss_c9118375a2400278590f29a3537769c986ef6e39.1920x1080.jpg?t=1682639497'},
#      {'id': 3,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/570/ss_f9ebafedaf2d5cfb80ef1f74baa18eb08cad6494.600x338.jpg?t=1682639497',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/570/ss_f9ebafedaf2d5cfb80ef1f74baa18eb08cad6494.1920x1080.jpg?t=1682639497'},
#      {'id': 4,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/570/ss_27b6345f22243bd6b885cc64c5cda74e4bd9c3e8.600x338.jpg?t=1682639497',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/570/ss_27b6345f22243bd6b885cc64c5cda74e4bd9c3e8.1920x1080.jpg?t=1682639497'},
#      {'id': 5,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/570/ss_b33a65678dc71cc98df4890e22a89601ee56a918.600x338.jpg?t=1682639497',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/570/ss_b33a65678dc71cc98df4890e22a89601ee56a918.1920x1080.jpg?t=1682639497'},
#      {'id': 6,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/570/ss_d0f973ce376ca5b6c08e081cb035e86ced105fa9.600x338.jpg?t=1682639497',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/570/ss_d0f973ce376ca5b6c08e081cb035e86ced105fa9.1920x1080.jpg?t=1682639497'},
#      {'id': 7,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/570/ss_1f3b5f5ccf8b159294914c3fe028128a787304b6.600x338.jpg?t=1682639497',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/570/ss_1f3b5f5ccf8b159294914c3fe028128a787304b6.1920x1080.jpg?t=1682639497'},
#      {'id': 8,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/570/ss_e0a92f15a6631a8186df79182d0fe28b5e37d8cb.600x338.jpg?t=1682639497',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/570/ss_e0a92f15a6631a8186df79182d0fe28b5e37d8cb.1920x1080.jpg?t=1682639497'},
#      {'id': 9,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/570/ss_86d675fdc73ba10462abb8f5ece7791c5047072c.600x338.jpg?t=1682639497',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/570/ss_86d675fdc73ba10462abb8f5ece7791c5047072c.1920x1080.jpg?t=1682639497'}],
#     'movies': [{'id': 256692021,
#       'name': 'Dota 2 - Join the Battle',
#       'thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/256692021/movie.293x165.jpg?t=1599609272',
#       'webm': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/256692021/movie480.webm?t=1599609272',
#        'max': 'http://cdn.akamai.steamstatic.com/steam/apps/256692021/movie_max.webm?t=1599609272'},
#       'mp4': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/256692021/movie480.mp4?t=1599609272',
#        'max': 'http://cdn.akamai.steamstatic.com/steam/apps/256692021/movie_max.mp4?t=1599609272'},
#       'highlight': True},
#      {'id': 256819789,
#       'name': 'Dota 2 - Sizzle Reel',
#       'thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/256819789/movie.293x165.jpg?t=1611689746',
#       'webm': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/256819789/movie480_vp9.webm?t=1611689746',
#        'max': 'http://cdn.akamai.steamstatic.com/steam/apps/256819789/movie_max_vp9.webm?t=1611689746'},
#       'mp4': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/256819789/movie480.mp4?t=1611689746',
#        'max': 'http://cdn.akamai.steamstatic.com/steam/apps/256819789/movie_max.mp4?t=1611689746'},
#       'highlight': True},
#      {'id': 2028243,
#       'name': 'Dota 2 - The Greeviling',
#       'thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/2028243/movie.293x165.jpg?t=1599609286',
#       'webm': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/2028243/movie480.webm?t=1599609286',
#        'max': 'http://cdn.akamai.steamstatic.com/steam/apps/2028243/movie_max.webm?t=1599609286'},
#       'mp4': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/2028243/movie480.mp4?t=1599609286',
#        'max': 'http://cdn.akamai.steamstatic.com/steam/apps/2028243/movie_max.mp4?t=1599609286'},
#       'highlight': False},
#      {'id': 81026,
#       'name': 'Dota 2 Gamescom Trailer',
#       'thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/81026/movie.293x165.jpg?t=1599609294',
#       'webm': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/81026/movie480.webm?t=1599609294',
#        'max': 'http://cdn.akamai.steamstatic.com/steam/apps/81026/movie_max.webm?t=1599609294'},
#       'mp4': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/81026/movie480.mp4?t=1599609294',
#        'max': 'http://cdn.akamai.steamstatic.com/steam/apps/81026/movie_max.mp4?t=1599609294'},
#       'highlight': False},
#      {'id': 2040250,
#       'name': 'Dota 2 Reborn - Custom Games Are Here',
#       'thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/2040250/movie.293x165.jpg?t=1599609302',
#       'webm': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/2040250/movie480.webm?t=1599609302',
#        'max': 'http://cdn.akamai.steamstatic.com/steam/apps/2040250/movie_max.webm?t=1599609302'},
#       'mp4': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/2040250/movie480.mp4?t=1599609302',
#        'max': 'http://cdn.akamai.steamstatic.com/steam/apps/2040250/movie_max.mp4?t=1599609302'},
#       'highlight': False}],
#     'recommendations': {'total': 14328},
#     'release_date': {'coming_soon': False, 'date': '9 Jul, 2013'},
#     'support_info': {'url': '', 'email': ''},
#     'background': 'https://cdn.akamai.steamstatic.com/steam/apps/570/page_bg_generated_v6b.jpg?t=1682639497',
#     'background_raw': 'https://cdn.akamai.steamstatic.com/steam/apps/570/page.bg.jpg?t=1682639497',
#     'content_descriptors': {'ids': [], 'notes': None}}}},
#  238960: {'238960': {'success': True,
#    'data': {'type': 'game',
#     'name': 'Path of Exile',
#     'steam_appid': 238960,
#     'required_age': 0,
#     'is_free': True,
#     'controller_support': 'full',
#     'detailed_description': 'You are an Exile, struggling to survive on the dark continent of Wraeclast, as you fight to earn power that will allow you to exact your revenge against those who wronged you. Created by hardcore gamers, Path of Exile is an online Action RPG set in a dark fantasy world. With a focus on visceral action combat, powerful items and deep character customization, Path of Exile is completely free and will never be pay-to-win.<h2 class="bb_tag">Key Features</h2><ul class="bb_ul"><li><strong>Freedom. Power. Revenge.</strong><br>Banished for your misdeeds to the dark, brutal world of Wraeclast, you play as the Duelist, Witch, Ranger, Templar, Marauder, Shadow or the Scion class. From forsaken shores through to the city of Oriath, explore Wraeclast and uncover the ancient secrets waiting for you.<br></li><li><strong>Unlimited Character Customization</strong><br>Create and customize hundreds of unique skill combinations from tradable itemized gems and our gigantic passive skill tree. Combine skill gems, support gems and trigger gems to create your own unique combination of power, defense and destruction.<br></li><li><strong>Deadly Missions</strong><br>The Masters each have their own style of mission and each of these missions has many variations. As you explore deeper into Wraeclast, the pool of available variations increases to challenge you in new ways. All of the Missions and their variations can occur anywhere in the game, including within end-game Maps.<br></li><li><strong>Dressed to Kill</strong><br>Path of Exile is all about items. Find, collect and trade magic, rare and unique items with arcane properties, then customize your character build around the deadliest combinations you possess.<br></li><li><strong>Brutal Competitive Play</strong><br>Compete in Leagues and Race Events that run as separate game worlds with their own ladders and economies to win valuable prizes.<br></li><li><strong>Customise Your Hideout</strong><br>Once unlocked, you may be taken to a Hideout, where you can create your own personalised town.<br></li><li><strong>Fair-To-Play. Never Pay-To-Win. </strong><br>We\'re committed to creating a fair playing field for all players. You cannot gain gameplay advantage by spending real money in Path of Exile.</li></ul>',
#     'about_the_game': 'You are an Exile, struggling to survive on the dark continent of Wraeclast, as you fight to earn power that will allow you to exact your revenge against those who wronged you. Created by hardcore gamers, Path of Exile is an online Action RPG set in a dark fantasy world. With a focus on visceral action combat, powerful items and deep character customization, Path of Exile is completely free and will never be pay-to-win.<h2 class="bb_tag">Key Features</h2><ul class="bb_ul"><li><strong>Freedom. Power. Revenge.</strong><br>Banished for your misdeeds to the dark, brutal world of Wraeclast, you play as the Duelist, Witch, Ranger, Templar, Marauder, Shadow or the Scion class. From forsaken shores through to the city of Oriath, explore Wraeclast and uncover the ancient secrets waiting for you.<br></li><li><strong>Unlimited Character Customization</strong><br>Create and customize hundreds of unique skill combinations from tradable itemized gems and our gigantic passive skill tree. Combine skill gems, support gems and trigger gems to create your own unique combination of power, defense and destruction.<br></li><li><strong>Deadly Missions</strong><br>The Masters each have their own style of mission and each of these missions has many variations. As you explore deeper into Wraeclast, the pool of available variations increases to challenge you in new ways. All of the Missions and their variations can occur anywhere in the game, including within end-game Maps.<br></li><li><strong>Dressed to Kill</strong><br>Path of Exile is all about items. Find, collect and trade magic, rare and unique items with arcane properties, then customize your character build around the deadliest combinations you possess.<br></li><li><strong>Brutal Competitive Play</strong><br>Compete in Leagues and Race Events that run as separate game worlds with their own ladders and economies to win valuable prizes.<br></li><li><strong>Customise Your Hideout</strong><br>Once unlocked, you may be taken to a Hideout, where you can create your own personalised town.<br></li><li><strong>Fair-To-Play. Never Pay-To-Win. </strong><br>We\'re committed to creating a fair playing field for all players. You cannot gain gameplay advantage by spending real money in Path of Exile.</li></ul>',
#     'short_description': 'You are an Exile, struggling to survive on the dark continent of Wraeclast, as you fight to earn power that will allow you to exact your revenge against those who wronged you. Created by hardcore gamers, Path of Exile is an online Action RPG set in a dark fantasy world.',
#     'supported_languages': 'English<strong>*</strong>, Portuguese - Brazil, Russian, Thai, French, German, Spanish - Spain, Japanese<br><strong>*</strong>languages with full audio support',
#     'reviews': '“PC Game of the Year 2013”<br>9 – <a href="https://steamcommunity.com/linkfilter/?url=http://www.gamespot.com/reviews/path-of-exile-review/1900-6415531/" target="_blank" rel=" noopener"  >Gamespot</a><br><br>“Path of Exile was a great game in 2013, but a slew of free expansions have only made it better. It’s one of the best ARPGs out there, and absolutely the best value.”<br>9 – <a href="https://www.pcgamer.com/path-of-exile-review/" target="_blank" rel=""  >PC Gamer (2018)</a><br>',
#     'header_image': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/header.jpg?t=1685655321',
#     'capsule_image': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/capsule_231x87.jpg?t=1685655321',
#     'capsule_imagev5': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/capsule_184x69.jpg?t=1685655321',
#     'website': 'http://www.pathofexile.com',
#     'pc_requirements': {'minimum': '<strong>Minimum:</strong><br><ul class="bb_ul"><li><strong>OS:</strong> Windows 10<br></li><li><strong>Processor:</strong> Quad core 2.6GHz x86-compatible<br></li><li><strong>Memory:</strong> 8 GB RAM<br></li><li><strong>Graphics:</strong> NVIDIA® GeForce® GTX 650 Ti or ATI Radeon™ HD 7850<br></li><li><strong>DirectX:</strong> Version 11<br></li><li><strong>Network:</strong> Broadband Internet connection<br></li><li><strong>Storage:</strong> 40 GB available space</li></ul>',
#      'recommended': '<strong>Recommended:</strong><br><ul class="bb_ul"><li><strong>OS:</strong> Windows 10<br></li><li><strong>Processor:</strong> Quad core 3.2GHz x64-compatible<br></li><li><strong>Memory:</strong> 16 GB RAM<br></li><li><strong>Graphics:</strong> NVIDIA® GeForce® GTX 1050 Ti or ATI Radeon™ RX560<br></li><li><strong>DirectX:</strong> Version 11<br></li><li><strong>Network:</strong> Broadband Internet connection<br></li><li><strong>Storage:</strong> 40 GB available space<br></li><li><strong>Additional Notes:</strong> Solid state storage is recommended</li></ul>'},
#     'mac_requirements': {'minimum': '<strong>Minimum:</strong><br><ul class="bb_ul"><li><strong>OS:</strong> macOS 10.13<br></li><li><strong>Processor:</strong> 2.6GHz quad-core Intel Core i7<br></li><li><strong>Memory:</strong> 8 GB RAM<br></li><li><strong>Graphics:</strong> Radeon Pro 450<br></li><li><strong>Network:</strong> Broadband Internet connection<br></li><li><strong>Storage:</strong> 40 GB available space</li></ul>',
#      'recommended': '<strong>Recommended:</strong><br><ul class="bb_ul"><li><strong>OS:</strong> macOS 10.15<br></li><li><strong>Processor:</strong> 2.6GHz hex-core Intel Core i7<br></li><li><strong>Memory:</strong> 16 GB RAM<br></li><li><strong>Graphics:</strong> Radeon Pro 555X<br></li><li><strong>Network:</strong> Broadband Internet connection<br></li><li><strong>Storage:</strong> 40 GB available space<br></li><li><strong>Additional Notes:</strong> Solid state storage is recommended</li></ul>'},
#     'linux_requirements': [],
#     'legal_notice': '(c) 2006 - 2023 Grinding Gear Games Ltd.',
#     'developers': ['Grinding Gear Games'],
#     'publishers': ['Grinding Gear Games'],
#     'packages': [306042],
#     'package_groups': [{'name': 'default',
#       'title': 'Buy Path of Exile',
#       'description': '',
#       'selection_text': 'Select a purchase option',
#       'save_text': '',
#       'display_type': 0,
#       'is_recurring_subscription': 'false',
#       'subs': [{'packageid': 306042,
#         'percent_savings_text': ' ',
#         'percent_savings': 0,
#         'option_text': 'Path of Exile - Commercial License (Free) - Free',
#         'option_description': '',
#         'can_get_free_license': '0',
#         'is_free_license': True,
#         'price_in_cents_with_discount': 0}]}],
#     'platforms': {'windows': True, 'mac': True, 'linux': False},
#     'metacritic': {'score': 86,
#      'url': 'https://www.metacritic.com/game/pc/path-of-exile?ftag=MCD-06-10aaa1f'},
#     'categories': [{'id': 2, 'description': 'Single-player'},
#      {'id': 1, 'description': 'Multi-player'},
#      {'id': 20, 'description': 'MMO'},
#      {'id': 49, 'description': 'PvP'},
#      {'id': 36, 'description': 'Online PvP'},
#      {'id': 9, 'description': 'Co-op'},
#      {'id': 22, 'description': 'Steam Achievements'},
#      {'id': 28, 'description': 'Full controller support'},
#      {'id': 29, 'description': 'Steam Trading Cards'},
#      {'id': 35, 'description': 'In-App Purchases'},
#      {'id': 42, 'description': 'Remote Play on Tablet'}],
#     'genres': [{'id': '1', 'description': 'Action'},
#      {'id': '25', 'description': 'Adventure'},
#      {'id': '37', 'description': 'Free to Play'},
#      {'id': '23', 'description': 'Indie'},
#      {'id': '29', 'description': 'Massively Multiplayer'},
#      {'id': '3', 'description': 'RPG'}],
#     'screenshots': [{'id': 0,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_a4cade6889788a13b53b071e819a822b8f763705.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_a4cade6889788a13b53b071e819a822b8f763705.1920x1080.jpg?t=1685655321'},
#      {'id': 1,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_00e9703b5b1ad038aac081440fea70f6091cbe93.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_00e9703b5b1ad038aac081440fea70f6091cbe93.1920x1080.jpg?t=1685655321'},
#      {'id': 2,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_7009075bce03d665bac3dc42975a9251bb572cbd.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_7009075bce03d665bac3dc42975a9251bb572cbd.1920x1080.jpg?t=1685655321'},
#      {'id': 3,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_aac776ae3c0c9b9e3116a2ae1a75818accbf36c0.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_aac776ae3c0c9b9e3116a2ae1a75818accbf36c0.1920x1080.jpg?t=1685655321'},
#      {'id': 4,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_51ac47ac43a7b9979c5d02fe08ff54f7e125b0a8.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_51ac47ac43a7b9979c5d02fe08ff54f7e125b0a8.1920x1080.jpg?t=1685655321'},
#      {'id': 5,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_8d4ae6f1696bd23d7f70703681c75b2ee749e1fd.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_8d4ae6f1696bd23d7f70703681c75b2ee749e1fd.1920x1080.jpg?t=1685655321'},
#      {'id': 6,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_d010f4b43cf4e0c9e6b60993f3f8c76d314904fd.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_d010f4b43cf4e0c9e6b60993f3f8c76d314904fd.1920x1080.jpg?t=1685655321'},
#      {'id': 7,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_dd49302e32b4067e347470b26c1e4f3c3eefd992.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_dd49302e32b4067e347470b26c1e4f3c3eefd992.1920x1080.jpg?t=1685655321'},
#      {'id': 8,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_fc1b084dcca227e3aa25c1840139d89f83991246.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_fc1b084dcca227e3aa25c1840139d89f83991246.1920x1080.jpg?t=1685655321'},
#      {'id': 9,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_4751825b253911dad7609350fc32406d8ac18010.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_4751825b253911dad7609350fc32406d8ac18010.1920x1080.jpg?t=1685655321'},
#      {'id': 10,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_40fa77890c74dd962fd665fa17440cc87003456e.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_40fa77890c74dd962fd665fa17440cc87003456e.1920x1080.jpg?t=1685655321'},
#      {'id': 11,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_8fba061cdefb4dcae3b6798959332b3a10315950.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_8fba061cdefb4dcae3b6798959332b3a10315950.1920x1080.jpg?t=1685655321'},
#      {'id': 12,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_26a455ad97d62bc249ea4c05ce0a0a9459874509.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_26a455ad97d62bc249ea4c05ce0a0a9459874509.1920x1080.jpg?t=1685655321'},
#      {'id': 13,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_27a595726e53eca84d6fc748bf7939fcab559029.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_27a595726e53eca84d6fc748bf7939fcab559029.1920x1080.jpg?t=1685655321'},
#      {'id': 14,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_f50b319eb3cd8c88acb2cc0359359d656ae06624.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_f50b319eb3cd8c88acb2cc0359359d656ae06624.1920x1080.jpg?t=1685655321'},
#      {'id': 15,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_39473243f527fac999e36e466c8f1a612a23663e.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_39473243f527fac999e36e466c8f1a612a23663e.1920x1080.jpg?t=1685655321'},
#      {'id': 16,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_ffb55a89e416bcf7c110c874368fe4bee9a0c90c.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_ffb55a89e416bcf7c110c874368fe4bee9a0c90c.1920x1080.jpg?t=1685655321'},
#      {'id': 17,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_56f238c9865f3d4d09085e422f95c6f2a75c1bc2.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_56f238c9865f3d4d09085e422f95c6f2a75c1bc2.1920x1080.jpg?t=1685655321'},
#      {'id': 18,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_b5dce91195cca32b4932221ff05040de4e1e5b7b.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_b5dce91195cca32b4932221ff05040de4e1e5b7b.1920x1080.jpg?t=1685655321'},
#      {'id': 19,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_62e6d4423881cfe9b2edf5101b877ce3ad28e50a.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_62e6d4423881cfe9b2edf5101b877ce3ad28e50a.1920x1080.jpg?t=1685655321'},
#      {'id': 20,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_4e00249b4e7cdc4b107596ad2a4004b4d1bd5504.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_4e00249b4e7cdc4b107596ad2a4004b4d1bd5504.1920x1080.jpg?t=1685655321'},
#      {'id': 21,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_e02714360a97ee235b5366220166c95bc8696798.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_e02714360a97ee235b5366220166c95bc8696798.1920x1080.jpg?t=1685655321'},
#      {'id': 22,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_3fd125a0f1d18eb2fbf320bf2bfc6451798ddb60.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_3fd125a0f1d18eb2fbf320bf2bfc6451798ddb60.1920x1080.jpg?t=1685655321'},
#      {'id': 23,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_b5a89bf11606da9c11199623736dcdf801dd14e0.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_b5a89bf11606da9c11199623736dcdf801dd14e0.1920x1080.jpg?t=1685655321'},
#      {'id': 24,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_53dcca3ace6a1690182e706a76e513e7c72b3afc.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_53dcca3ace6a1690182e706a76e513e7c72b3afc.1920x1080.jpg?t=1685655321'},
#      {'id': 25,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_fb2566dded30e498ed5bc30105e24d9a27b081cc.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_fb2566dded30e498ed5bc30105e24d9a27b081cc.1920x1080.jpg?t=1685655321'},
#      {'id': 26,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_9e66805f617cb65b5899b8a8d07d3cff05452bc5.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_9e66805f617cb65b5899b8a8d07d3cff05452bc5.1920x1080.jpg?t=1685655321'},
#      {'id': 28,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_8c3a5f06867e0ba77d2f3aece49a29193ea10ffe.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_8c3a5f06867e0ba77d2f3aece49a29193ea10ffe.1920x1080.jpg?t=1685655321'},
#      {'id': 29,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_d9be0bd1c3d96c085bbd02b9c4948f2d338a05f3.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_d9be0bd1c3d96c085bbd02b9c4948f2d338a05f3.1920x1080.jpg?t=1685655321'},
#      {'id': 30,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_9631a71aed7d3480b4c98aa413865c29788d4382.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_9631a71aed7d3480b4c98aa413865c29788d4382.1920x1080.jpg?t=1685655321'},
#      {'id': 31,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_4b8960b350129c113df4f891e08997e493f428a8.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_4b8960b350129c113df4f891e08997e493f428a8.1920x1080.jpg?t=1685655321'},
#      {'id': 32,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_4c205a15685d3f324d265de78394dbb5f7c6dd35.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_4c205a15685d3f324d265de78394dbb5f7c6dd35.1920x1080.jpg?t=1685655321'},
#      {'id': 33,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_d960f8f88cbd09b505ae595305bd6eb58bef0c0f.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_d960f8f88cbd09b505ae595305bd6eb58bef0c0f.1920x1080.jpg?t=1685655321'},
#      {'id': 34,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_0a469c31245724538a8c2214376980e8afb73b81.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_0a469c31245724538a8c2214376980e8afb73b81.1920x1080.jpg?t=1685655321'},
#      {'id': 35,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_84ae7e83393c824db65bd135186cc2f34e0e3b5d.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_84ae7e83393c824db65bd135186cc2f34e0e3b5d.1920x1080.jpg?t=1685655321'},
#      {'id': 36,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_4cfc694787b77cb069b5e9d545773037f1e09246.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_4cfc694787b77cb069b5e9d545773037f1e09246.1920x1080.jpg?t=1685655321'},
#      {'id': 37,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_113e35bb756cd089a8834cb78f6d063d725a2f1a.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_113e35bb756cd089a8834cb78f6d063d725a2f1a.1920x1080.jpg?t=1685655321'},
#      {'id': 38,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_30167e3079b452cf853e4f4edefe16330447ba58.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_30167e3079b452cf853e4f4edefe16330447ba58.1920x1080.jpg?t=1685655321'},
#      {'id': 39,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_af60e0e2d10544b2377b0011d477ea1d7c30e3d1.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_af60e0e2d10544b2377b0011d477ea1d7c30e3d1.1920x1080.jpg?t=1685655321'},
#      {'id': 40,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_1a7fa5f7fc74b6290ef28e72ed8c39c146590d8e.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_1a7fa5f7fc74b6290ef28e72ed8c39c146590d8e.1920x1080.jpg?t=1685655321'},
#      {'id': 41,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_f6bfe21161fc3068c7d9a934279295fbb60325d5.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_f6bfe21161fc3068c7d9a934279295fbb60325d5.1920x1080.jpg?t=1685655321'},
#      {'id': 42,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_ccfa5e377d4c1803718e0f950582d7e4dda03c2b.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_ccfa5e377d4c1803718e0f950582d7e4dda03c2b.1920x1080.jpg?t=1685655321'},
#      {'id': 43,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_9b27cf3dbd876d1690396b5a73ffc84fc21341d3.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_9b27cf3dbd876d1690396b5a73ffc84fc21341d3.1920x1080.jpg?t=1685655321'},
#      {'id': 44,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_cccefc742825f2e38877a1d6e13b682efa18cc44.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_cccefc742825f2e38877a1d6e13b682efa18cc44.1920x1080.jpg?t=1685655321'},
#      {'id': 45,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_b8f5e3ccd9f4ebca0d19e91dd579bd2103cdf676.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_b8f5e3ccd9f4ebca0d19e91dd579bd2103cdf676.1920x1080.jpg?t=1685655321'},
#      {'id': 46,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_7670f5757a5fed703164fc9983801e5d9d969b89.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_7670f5757a5fed703164fc9983801e5d9d969b89.1920x1080.jpg?t=1685655321'},
#      {'id': 47,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_e4fede832126017b3372bf7b7fdd3139dc818d0a.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_e4fede832126017b3372bf7b7fdd3139dc818d0a.1920x1080.jpg?t=1685655321'},
#      {'id': 48,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_4621f3cdd7db9e79eb7f2257ca103a1386d74d9f.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_4621f3cdd7db9e79eb7f2257ca103a1386d74d9f.1920x1080.jpg?t=1685655321'},
#      {'id': 50,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_0cbbaba79ed7a0d8f24b77b4ae5fa7dc3543a4f5.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_0cbbaba79ed7a0d8f24b77b4ae5fa7dc3543a4f5.1920x1080.jpg?t=1685655321'},
#      {'id': 51,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_f2dda90cf0b926ce00d622d16942065a6c0bb442.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_f2dda90cf0b926ce00d622d16942065a6c0bb442.1920x1080.jpg?t=1685655321'},
#      {'id': 52,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_badd848a8fca37866762e0a8d8212559aab1d220.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_badd848a8fca37866762e0a8d8212559aab1d220.1920x1080.jpg?t=1685655321'},
#      {'id': 54,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_d3d5c8df61a7a52b8670b27dbe7c51d881388b61.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_d3d5c8df61a7a52b8670b27dbe7c51d881388b61.1920x1080.jpg?t=1685655321'},
#      {'id': 55,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_e2ccb759f4ffebc0bbd514c52eb3ec08b8eb3433.600x338.jpg?t=1685655321',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/ss_e2ccb759f4ffebc0bbd514c52eb3ec08b8eb3433.1920x1080.jpg?t=1685655321'}],
#     'movies': [{'id': 256939794,
#       'name': 'Path of Exile: Crucible Trailer',
#       'thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/256939794/movie.293x165.jpg?t=1680737807',
#       'webm': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/256939794/movie480_vp9.webm?t=1680737807',
#        'max': 'http://cdn.akamai.steamstatic.com/steam/apps/256939794/movie_max_vp9.webm?t=1680737807'},
#       'mp4': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/256939794/movie480.mp4?t=1680737807',
#        'max': 'http://cdn.akamai.steamstatic.com/steam/apps/256939794/movie_max.mp4?t=1680737807'},
#       'highlight': True},
#      {'id': 256918980,
#       'name': 'Path of Exile: The Forbidden Sanctum Trailer',
#       'thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/256918980/movie.293x165.jpg?t=1669970948',
#       'webm': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/256918980/movie480_vp9.webm?t=1669970948',
#        'max': 'http://cdn.akamai.steamstatic.com/steam/apps/256918980/movie_max_vp9.webm?t=1669970948'},
#       'mp4': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/256918980/movie480.mp4?t=1669970948',
#        'max': 'http://cdn.akamai.steamstatic.com/steam/apps/256918980/movie_max.mp4?t=1669970948'},
#       'highlight': True},
#      {'id': 256902787,
#       'name': 'Path of Exile: Lake of Kalandra Trailer',
#       'thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/256902787/movie.293x165.jpg?t=1661471411',
#       'webm': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/256902787/movie480_vp9.webm?t=1661471411',
#        'max': 'http://cdn.akamai.steamstatic.com/steam/apps/256902787/movie_max_vp9.webm?t=1661471411'},
#       'mp4': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/256902787/movie480.mp4?t=1661471411',
#        'max': 'http://cdn.akamai.steamstatic.com/steam/apps/256902787/movie_max.mp4?t=1661471411'},
#       'highlight': True},
#      {'id': 256886066,
#       'name': 'Path of Exile: Sentinel Trailer',
#       'thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/256886066/movie.293x165.jpg?t=1652231607',
#       'webm': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/256886066/movie480_vp9.webm?t=1652231607',
#        'max': 'http://cdn.akamai.steamstatic.com/steam/apps/256886066/movie_max_vp9.webm?t=1652231607'},
#       'mp4': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/256886066/movie480.mp4?t=1652231607',
#        'max': 'http://cdn.akamai.steamstatic.com/steam/apps/256886066/movie_max.mp4?t=1652231607'},
#       'highlight': True},
#      {'id': 256871023,
#       'name': 'Path of Exile: Siege of the Atlas Trailer',
#       'thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/256871023/movie.293x165.jpg?t=1643315562',
#       'webm': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/256871023/movie480_vp9.webm?t=1643315562',
#        'max': 'http://cdn.akamai.steamstatic.com/steam/apps/256871023/movie_max_vp9.webm?t=1643315562'},
#       'mp4': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/256871023/movie480.mp4?t=1643315562',
#        'max': 'http://cdn.akamai.steamstatic.com/steam/apps/256871023/movie_max.mp4?t=1643315562'},
#       'highlight': True},
#      {'id': 256830037,
#       'name': 'Path of Exile 2 Second Trailer',
#       'thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/256830037/movie.293x165.jpg?t=1627066043',
#       'webm': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/256830037/movie480_vp9.webm?t=1627066043',
#        'max': 'http://cdn.akamai.steamstatic.com/steam/apps/256830037/movie_max_vp9.webm?t=1627066043'},
#       'mp4': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/256830037/movie480.mp4?t=1627066043',
#        'max': 'http://cdn.akamai.steamstatic.com/steam/apps/256830037/movie_max.mp4?t=1627066043'},
#       'highlight': True}],
#     'recommendations': {'total': 1066},
#     'achievements': {'total': 127,
#      'highlighted': [{'name': 'Challenger',
#        'path': 'https://cdn.akamai.steamstatic.com/steamcommunity/public/images/apps/238960/4243cfe9a30928546145a8d6e29ab32c8e5ca766.jpg'},
#       {'name': 'Leader',
#        'path': 'https://cdn.akamai.steamstatic.com/steamcommunity/public/images/apps/238960/bccdced51cd401dde84b6b07cf96812b42250408.jpg'},
#       {'name': 'Lord',
#        'path': 'https://cdn.akamai.steamstatic.com/steamcommunity/public/images/apps/238960/29c0f97a1d979ebaca97f81e7b364bc07e289bab.jpg'},
#       {'name': 'Fearless',
#        'path': 'https://cdn.akamai.steamstatic.com/steamcommunity/public/images/apps/238960/1181404052afa618aa1864bddc011b4363421b23.jpg'},
#       {'name': 'Dauntless',
#        'path': 'https://cdn.akamai.steamstatic.com/steamcommunity/public/images/apps/238960/27d51b49f7f1c94b2616673dacd8cb4157c353f7.jpg'},
#       {'name': 'Indomitable',
#        'path': 'https://cdn.akamai.steamstatic.com/steamcommunity/public/images/apps/238960/4fff51fe37a8d4034e49d811ccddf27d4d332541.jpg'},
#       {'name': 'Mercy Killing',
#        'path': 'https://cdn.akamai.steamstatic.com/steamcommunity/public/images/apps/238960/daa9f834d636f840070d48f1aeb0b785f92905b3.jpg'},
#       {'name': 'The Star of Wraeclast',
#        'path': 'https://cdn.akamai.steamstatic.com/steamcommunity/public/images/apps/238960/e630c876dc24194e16eb2bcbdc936b18897ecda9.jpg'},
#       {'name': 'A New Dawn',
#        'path': 'https://cdn.akamai.steamstatic.com/steamcommunity/public/images/apps/238960/eac6f86a71180aa2f702d6a579bf86eb60f9e9fa.jpg'},
#       {'name': 'Rest for the Wicked',
#        'path': 'https://cdn.akamai.steamstatic.com/steamcommunity/public/images/apps/238960/11fac40fd16a77efeadf82cdeca8ed8967637646.jpg'}]},
#     'release_date': {'coming_soon': False, 'date': '23 Oct, 2013'},
#     'support_info': {'url': 'https://www.pathofexile.com/support',
#      'email': 'support@grindinggear.com'},
#     'background': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/page_bg_generated_v6b.jpg?t=1685655321',
#     'background_raw': 'https://cdn.akamai.steamstatic.com/steam/apps/238960/page.bg.jpg?t=1685655321',
#     'content_descriptors': {'ids': [1, 2, 5], 'notes': None}}}},
#  730: {'730': {'success': True,
#    'data': {'type': 'game',
#     'name': 'Counter-Strike: Global Offensive',
#     'steam_appid': 730,
#     'required_age': 0,
#     'is_free': True,
#     'controller_support': 'full',
# ...
#      {'id': 21,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_fa24f346de8b6bef1f1c7b90342806b8e14193d2.600x338.jpg?t=1684394834',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_fa24f346de8b6bef1f1c7b90342806b8e14193d2.1920x1080.jpg?t=1684394834'},
#      {'id': 22,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_b8a568a50d62516fb04a353e28fdbd4d874761dc.600x338.jpg?t=1684394834',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_b8a568a50d62516fb04a353e28fdbd4d874761dc.1920x1080.jpg?t=1684394834'},
#      {'id': 23,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_71c358420ddd0def7104d0a775a815693e8d0ada.600x338.jpg?t=1684394834',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_71c358420ddd0def7104d0a775a815693e8d0ada.1920x1080.jpg?t=1684394834'},
#      {'id': 24,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_a7e0ea84457a7758869837e99241c26be5fc5cd8.600x338.jpg?t=1684394834',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_a7e0ea84457a7758869837e99241c26be5fc5cd8.1920x1080.jpg?t=1684394834'},
#      {'id': 25,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_7443bf9ebb34a7ca716e17639e72a7ad849cf76b.600x338.jpg?t=1684394834',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_7443bf9ebb34a7ca716e17639e72a7ad849cf76b.1920x1080.jpg?t=1684394834'},
#      {'id': 26,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_9061d7214c856fa13e8f24e1021ac7c0d89df33f.600x338.jpg?t=1684394834',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_9061d7214c856fa13e8f24e1021ac7c0d89df33f.1920x1080.jpg?t=1684394834'},
#      {'id': 27,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_9db7fde9cdafe02ed55ee338dd3e192586eb588d.600x338.jpg?t=1684394834',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_9db7fde9cdafe02ed55ee338dd3e192586eb588d.1920x1080.jpg?t=1684394834'},
#      {'id': 28,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_426762462c7ffac84703867c20816dbc57b3b4ea.600x338.jpg?t=1684394834',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_426762462c7ffac84703867c20816dbc57b3b4ea.1920x1080.jpg?t=1684394834'},
#      {'id': 29,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_24d60fa5915bc4be214c74d5fee158402e0096cb.600x338.jpg?t=1684394834',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_24d60fa5915bc4be214c74d5fee158402e0096cb.1920x1080.jpg?t=1684394834'},
#      {'id': 30,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_53a15e38a419fee94c9bece6cea08124fab2c10c.600x338.jpg?t=1684394834',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_53a15e38a419fee94c9bece6cea08124fab2c10c.1920x1080.jpg?t=1684394834'},
#      {'id': 31,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_e0b54dc41adca1eea698970f03d40a993b35f63f.600x338.jpg?t=1684394834',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_e0b54dc41adca1eea698970f03d40a993b35f63f.1920x1080.jpg?t=1684394834'},
#      {'id': 32,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_2f5ae0e58b3bfb1f67acafb873524ef075d0db26.600x338.jpg?t=1684394834',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_2f5ae0e58b3bfb1f67acafb873524ef075d0db26.1920x1080.jpg?t=1684394834'},
#      {'id': 33,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_03a148373a286a14be4570fc1bc5093f83752525.600x338.jpg?t=1684394834',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_03a148373a286a14be4570fc1bc5093f83752525.1920x1080.jpg?t=1684394834'},
#      {'id': 34,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_129a2f818727036acb5c4630a8dc5e1adea79b8d.600x338.jpg?t=1684394834',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_129a2f818727036acb5c4630a8dc5e1adea79b8d.1920x1080.jpg?t=1684394834'},
#      {'id': 35,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_0b34e5e9c8bc00fb266844f34e5530eea87233ea.600x338.jpg?t=1684394834',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_0b34e5e9c8bc00fb266844f34e5530eea87233ea.1920x1080.jpg?t=1684394834'},
#      {'id': 36,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_f73ce71bda915964987aeb5844e31e5f03efc0df.600x338.jpg?t=1684394834',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_f73ce71bda915964987aeb5844e31e5f03efc0df.1920x1080.jpg?t=1684394834'},
#      {'id': 37,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_dee660caf34ff0bee82e4604e5a634791d4f1a5f.600x338.jpg?t=1684394834',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_dee660caf34ff0bee82e4604e5a634791d4f1a5f.1920x1080.jpg?t=1684394834'},
#      {'id': 38,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_524a15ca2d0c2a9c0b59402e05cd53e85300e7c2.600x338.jpg?t=1684394834',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_524a15ca2d0c2a9c0b59402e05cd53e85300e7c2.1920x1080.jpg?t=1684394834'},
#      {'id': 39,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_6c49d35db66c109c3ef2a6fbf2dd6e7ff2d1cfd4.600x338.jpg?t=1684394834',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_6c49d35db66c109c3ef2a6fbf2dd6e7ff2d1cfd4.1920x1080.jpg?t=1684394834'},
#      {'id': 40,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_e6f08f8e5259a687d8377845c70d7fca3ca5e3a9.600x338.jpg?t=1684394834',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_e6f08f8e5259a687d8377845c70d7fca3ca5e3a9.1920x1080.jpg?t=1684394834'},
#      {'id': 41,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_b0ecdb1fa1fa9295c84527e82fc851808f0a6d5a.600x338.jpg?t=1684394834',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_b0ecdb1fa1fa9295c84527e82fc851808f0a6d5a.1920x1080.jpg?t=1684394834'},
#      {'id': 42,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_94b242cf382a438fb01be728df9add12893485c7.600x338.jpg?t=1684394834',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_94b242cf382a438fb01be728df9add12893485c7.1920x1080.jpg?t=1684394834'},
#      {'id': 43,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_23a04eeb960d88a40f1ee520e7541b29bd4c32d5.600x338.jpg?t=1684394834',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_23a04eeb960d88a40f1ee520e7541b29bd4c32d5.1920x1080.jpg?t=1684394834'},
#      {'id': 44,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_e76825bdbef1f314ac797f702b6aa52afbb5546f.600x338.jpg?t=1684394834',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_e76825bdbef1f314ac797f702b6aa52afbb5546f.1920x1080.jpg?t=1684394834'},
#      {'id': 45,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_0175d2f3e0565b87b3164bbadcf3fe27e4866448.600x338.jpg?t=1684394834',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_0175d2f3e0565b87b3164bbadcf3fe27e4866448.1920x1080.jpg?t=1684394834'},
#      {'id': 46,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_7b04a7489f2827c495c43447c59f478fb5f7d9db.600x338.jpg?t=1684394834',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_7b04a7489f2827c495c43447c59f478fb5f7d9db.1920x1080.jpg?t=1684394834'},
#      {'id': 47,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_b6b4beebcbed55e95bd8153419ab42d3f427090a.600x338.jpg?t=1684394834',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_b6b4beebcbed55e95bd8153419ab42d3f427090a.1920x1080.jpg?t=1684394834'},
#      {'id': 48,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_0bbcbc95d0218e1b55aa86592990c7a8b05aeadb.600x338.jpg?t=1684394834',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_0bbcbc95d0218e1b55aa86592990c7a8b05aeadb.1920x1080.jpg?t=1684394834'},
#      {'id': 49,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_cd6d8da12617e67110f2b537de17ad74b50e9375.600x338.jpg?t=1684394834',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_cd6d8da12617e67110f2b537de17ad74b50e9375.1920x1080.jpg?t=1684394834'},
#      {'id': 50,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_b261b781aa51de099855750dfd090ab1f2dfbb70.600x338.jpg?t=1684394834',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_b261b781aa51de099855750dfd090ab1f2dfbb70.1920x1080.jpg?t=1684394834'},
#      {'id': 51,
#       'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_fe1492115942529ce8e147cfecd79799dc89846d.600x338.jpg?t=1684394834',
#       'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/ss_fe1492115942529ce8e147cfecd79799dc89846d.1920x1080.jpg?t=1684394834'}],
#     'movies': [{'id': 256886955,
#       'name': 'V Rising Launch Trailer',
#       'thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/256886955/movie.293x165.jpg?t=1683289356',
#       'webm': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/256886955/movie480_vp9.webm?t=1683289356',
#        'max': 'http://cdn.akamai.steamstatic.com/steam/apps/256886955/movie_max_vp9.webm?t=1683289356'},
#       'mp4': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/256886955/movie480.mp4?t=1683289356',
#        'max': 'http://cdn.akamai.steamstatic.com/steam/apps/256886955/movie_max.mp4?t=1683289356'},
#       'highlight': True},
#      {'id': 256947251,
#       'name': 'V Rising Full Gloomrot Gameplay Trailer',
#       'thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/256947251/movie.293x165.jpg?t=1684255462',
#       'webm': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/256947251/movie480_vp9.webm?t=1684255462',
#        'max': 'http://cdn.akamai.steamstatic.com/steam/apps/256947251/movie_max_vp9.webm?t=1684255462'},
#       'mp4': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/256947251/movie480.mp4?t=1684255462',
#        'max': 'http://cdn.akamai.steamstatic.com/steam/apps/256947251/movie_max.mp4?t=1684255462'},
#       'highlight': True},
#      {'id': 256941633,
#       'name': 'Secrets of Gloomrot Cinematic Trailer',
#       'thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/256941633/movie.293x165.jpg?t=1683289364',
#       'webm': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/256941633/movie480_vp9.webm?t=1683289364',
#        'max': 'http://cdn.akamai.steamstatic.com/steam/apps/256941633/movie_max_vp9.webm?t=1683289364'},
#       'mp4': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/256941633/movie480.mp4?t=1683289364',
#        'max': 'http://cdn.akamai.steamstatic.com/steam/apps/256941633/movie_max.mp4?t=1683289364'},
#       'highlight': True},
#      {'id': 256944789,
#       'name': 'Enter Gloomrot Gameplay Trailer',
#       'thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/256944789/movie.293x165.jpg?t=1683289360',
#       'webm': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/256944789/movie480_vp9.webm?t=1683289360',
#        'max': 'http://cdn.akamai.steamstatic.com/steam/apps/256944789/movie_max_vp9.webm?t=1683289360'},
#       'mp4': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/256944789/movie480.mp4?t=1683289360',
#        'max': 'http://cdn.akamai.steamstatic.com/steam/apps/256944789/movie_max.mp4?t=1683289360'},
#       'highlight': True},
#      {'id': 256912509,
#       'name': '2022 V Rising Halloween Trailer',
#       'thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/256912509/movie.293x165.jpg?t=1683289368',
#       'webm': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/256912509/movie480_vp9.webm?t=1683289368',
#        'max': 'http://cdn.akamai.steamstatic.com/steam/apps/256912509/movie_max_vp9.webm?t=1683289368'},
#       'mp4': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/256912509/movie480.mp4?t=1683289368',
#        'max': 'http://cdn.akamai.steamstatic.com/steam/apps/256912509/movie_max.mp4?t=1683289368'},
#       'highlight': True},
#      {'id': 256851663,
#       'name': 'V Rising Gameplay Trailer',
#       'thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/256851663/movie.293x165.jpg?t=1683289373',
#       'webm': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/256851663/movie480_vp9.webm?t=1683289373',
#        'max': 'http://cdn.akamai.steamstatic.com/steam/apps/256851663/movie_max_vp9.webm?t=1683289373'},
#       'mp4': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/256851663/movie480.mp4?t=1683289373',
#        'max': 'http://cdn.akamai.steamstatic.com/steam/apps/256851663/movie_max.mp4?t=1683289373'},
#       'highlight': True},
#      {'id': 256878458,
#       'name': 'V Rising Closed Beta Trailer',
#       'thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/256878458/movie.293x165.jpg?t=1683289377',
#       'webm': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/256878458/movie480_vp9.webm?t=1683289377',
#        'max': 'http://cdn.akamai.steamstatic.com/steam/apps/256878458/movie_max_vp9.webm?t=1683289377'},
#       'mp4': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/256878458/movie480.mp4?t=1683289377',
#        'max': 'http://cdn.akamai.steamstatic.com/steam/apps/256878458/movie_max.mp4?t=1683289377'},
#       'highlight': True},
#      {'id': 256857886,
#       'name': '2021 V Rising Halloween Trailer',
#       'thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/256857886/movie.293x165.jpg?t=1683289381',
#       'webm': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/256857886/movie480_vp9.webm?t=1683289381',
#        'max': 'http://cdn.akamai.steamstatic.com/steam/apps/256857886/movie_max_vp9.webm?t=1683289381'},
#       'mp4': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/256857886/movie480.mp4?t=1683289381',
#        'max': 'http://cdn.akamai.steamstatic.com/steam/apps/256857886/movie_max.mp4?t=1683289381'},
#       'highlight': True},
#      {'id': 256832650,
#       'name': 'V Rising Reveal Trailer',
#       'thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/256832650/movie.293x165.jpg?t=1683289385',
#       'webm': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/256832650/movie480_vp9.webm?t=1683289385',
#        'max': 'http://cdn.akamai.steamstatic.com/steam/apps/256832650/movie_max_vp9.webm?t=1683289385'},
#       'mp4': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/256832650/movie480.mp4?t=1683289385',
#        'max': 'http://cdn.akamai.steamstatic.com/steam/apps/256832650/movie_max.mp4?t=1683289385'},
#       'highlight': True}],
#     'recommendations': {'total': 59660},
#     'release_date': {'coming_soon': False, 'date': '17 May, 2022'},
#     'support_info': {'url': 'https://discord.gg/4RQ98aqSTh',
#      'email': 'support@playvrising.com'},
#     'background': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/page_bg_generated_v6b.jpg?t=1684394834',
#     'background_raw': 'https://cdn.akamai.steamstatic.com/steam/apps/1604030/page.bg.jpg?t=1684394834',
#     'content_descriptors': {'ids': [], 'notes': None}}}}}

# %%
apps_data[570]["570"]["data"]["genres"][0]["description"]
# Out:
# 'Action'

# %%
apps_data[570]["570"]["data"]["developers"]
# Out:
# ['Valve']

# %%
# Steam Store app link

app_id_store_url = "https://store.steampowered.com/app/" + str(app_id)
app_id_store_url
# Out:
# 'https://store.steampowered.com/app/1604030'

# %%
# Official website app link

apps_data[570]["570"]["data"]["website"]
# Out:
# 'http://www.dota2.com/'

# %%
# Official website app link

mc_score = apps_data[570]["570"]["data"]["metacritic"]["score"]
mc_link = apps_data[570]["570"]["data"]["metacritic"]["url"]

print("The score this game has been given on metacritic.com is :", mc_score,"/ 100")
print("You can find this game's review here :", mc_link)
# Out:
# The score this game has been given on metacritic.com is : 90 / 100
# You can find this game's review here : https://www.metacritic.com/game/pc/dota-2?ftag=MCD-06-10aaa1f

# %%
apps_data[570]["570"]["data"]["detailed_description"]
# Out:
# "<strong>The most-played game on Steam.</strong><br>Every day, millions of players worldwide enter battle as one of over a hundred Dota heroes. And no matter if it's their 10th hour of play or 1,000th, there's always something new to discover. With regular updates that ensure a constant evolution of gameplay, features, and heroes, Dota 2 has truly taken on a life of its own.<br><br><strong>One Battlefield. Infinite Possibilities.</strong><br>When it comes to diversity of heroes, abilities, and powerful items, Dota boasts an endless array—no two games are the same. Any hero can fill multiple roles, and there's an abundance of items to help meet the needs of each game. Dota doesn't provide limitations on how to play, it empowers you to express your own style.<br><br><strong>All heroes are free.</strong><br>Competitive balance is Dota's crown jewel, and to ensure everyone is playing on an even field, the core content of the game—like the vast pool of heroes—is available to all players. Fans can collect cosmetics for heroes and fun add-ons for the world they inhabit, but everything you need to play is already included before you join your first match.<br><br><strong>Bring your friends and party up.</strong><br>Dota is deep, and constantly evolving, but it's never too late to join. <br>Learn the ropes playing co-op vs. bots. Sharpen your skills in the hero demo mode. Jump into the behavior- and skill-based matchmaking system that ensures you'll <br>be matched with the right players each game."

# %%
apps_data[570]["570"]["data"]["header_image"]
# Out:
# 'https://cdn.akamai.steamstatic.com/steam/apps/570/header.jpg?t=1682639497'

# %%
top_10_apps_ids_genres = []

for x in top_10_apps_ids:
    for item in apps_data[x][str(x)]["data"]["genres"]:
        genre = item["description"]
        top_10_apps_ids_genres.append(genre)


        pprint.pprint(genre)
genre
# Out:
# 'Action'
# 'Free to Play'
# 'Strategy'
# 'Action'
# 'Adventure'
# 'Free to Play'
# 'Indie'
# 'Massively Multiplayer'
# 'RPG'
# 'Action'
# 'Free to Play'
# 'Action'
# 'Adventure'
# 'Simulation'
# 'Action'
# 'RPG'
# 'Adventure'
# 'Indie'
# 'Simulation'
# 'Strategy'
# 'Early Access'
# 'Adventure'
# 'RPG'
# 'Strategy'
# 'Action'
# 'Free to Play'
# 'Action'
# 'Indie'
# 'Racing'
# 'Sports'
# 'Action'
# 'Adventure'
# 'Massively Multiplayer'
# 'Early Access'
# 'Early Access'

# %%
top_10_apps_ids_categories = []

for x in top_10_apps_ids:
    for item in apps_data[x][str(x)]["data"]["categories"]:
        category = item["description"]
        top_10_apps_ids_categories.append(category)
        
        
        pprint.pprint(category)
category
# Out:
# 'Multi-player'
# 'Co-op'
# 'Steam Trading Cards'
# 'Steam Workshop'
# 'SteamVR Collectibles'
# 'In-App Purchases'
# 'Valve Anti-Cheat enabled'
# 'Single-player'
# 'Multi-player'
# 'MMO'
# 'PvP'
# 'Online PvP'
# 'Co-op'
# 'Steam Achievements'
# 'Full controller support'
# 'Steam Trading Cards'
# 'In-App Purchases'
# 'Remote Play on Tablet'
# 'Multi-player'
# 'Steam Achievements'
# 'Full controller support'
# 'Steam Trading Cards'
# 'Steam Workshop'
# 'In-App Purchases'
# 'Valve Anti-Cheat enabled'
# 'Stats'
# 'Remote Play on Phone'
# 'Remote Play on Tablet'
# 'Remote Play on TV'
# 'Multi-player'
# 'Co-op'
# 'Cross-Platform Multiplayer'
# 'Remote Play on Tablet'
# 'Single-player'
# 'Multi-player'
# 'PvP'
# 'Online PvP'
# 'Co-op'
# 'Online Co-op'
# 'Steam Achievements'
# 'Full controller support'
# 'Steam Trading Cards'
# 'Steam Cloud'
# 'Single-player'
# 'Multi-player'
# 'Co-op'
# 'Online Co-op'
# 'Cross-Platform Multiplayer'
# 'Steam Cloud'
# 'Remote Play on Tablet'
# 'Single-player'
# 'Multi-player'
# 'PvP'
# 'Online PvP'
# 'Shared/Split Screen PvP'
# 'Co-op'
# 'Online Co-op'
# 'Shared/Split Screen Co-op'
# 'Shared/Split Screen'
# 'Steam Achievements'
# 'Full controller support'
# 'Steam Trading Cards'
# 'Captions available'
# 'Steam Workshop'
# 'Steam Cloud'
# 'Includes level editor'
# 'Remote Play on Tablet'
# 'Remote Play on TV'
# 'Remote Play Together'
# 'Multi-player'
# 'Cross-Platform Multiplayer'
# 'Steam Achievements'
# 'Steam Trading Cards'
# 'Captions available'
# 'Steam Workshop'
# 'In-App Purchases'
# 'Partial Controller Support'
# 'Valve Anti-Cheat enabled'
# 'Stats'
# 'Includes level editor'
# 'Commentary available'
# 'Remote Play on Phone'
# 'Remote Play on Tablet'
# 'Single-player'
# 'Multi-player'
# 'PvP'
# 'Online PvP'
# 'Shared/Split Screen PvP'
# 'Co-op'
# 'Online Co-op'
# 'Shared/Split Screen Co-op'
# 'Shared/Split Screen'
# 'Cross-Platform Multiplayer'
# 'Steam Achievements'
# 'Full controller support'
# 'Steam Trading Cards'
# 'Steam Workshop'
# 'Steam Cloud'
# 'Stats'
# 'Remote Play on Phone'
# 'Remote Play on Tablet'
# 'Remote Play on TV'
# 'Remote Play Together'
# 'Single-player'
# 'Multi-player'
# 'PvP'
# 'Online PvP'
# 'LAN PvP'
# 'Co-op'
# 'Online Co-op'
# 'LAN Co-op'
# 'Steam Cloud'
# 'Steam Cloud'

# %%
genres_value_counts = {}

# Safety reset
for key in genres_value_counts:
    genres_value_counts[key] = 0
    
# Count the occurrences of each value in the list
for value in top_10_apps_ids_genres:
    if value in genres_value_counts:
        genres_value_counts[value] += 1
    else:
        genres_value_counts[value] = 1

# Get the count for each unique value
for value, count in genres_value_counts.items():
    pprint.pprint(f"{value}: {count}")
# Out:
# 'Action: 8'
# 'Free to Play: 4'
# 'Strategy: 3'
# 'Adventure: 5'
# 'Indie: 3'
# 'Massively Multiplayer: 2'
# 'RPG: 3'
# 'Simulation: 2'
# 'Early Access: 2'
# 'Racing: 1'
# 'Sports: 1'

# %%
categories_value_counts = {}

# Safety reset
for key in categories_value_counts:
    categories_value_counts[key] = 0
    
# Count the occurrences of each value in the list
for value in top_10_apps_ids_categories:
    if value in categories_value_counts:
        categories_value_counts[value] += 1
    else:
        categories_value_counts[value] = 1

# Get the count for each unique value
for value, count in categories_value_counts.items():
    pprint.pprint(f"{value}: {count}")
# Out:
# 'Multi-player: 10'
# 'Co-op: 8'
# 'Steam Trading Cards: 7'
# 'Steam Workshop: 5'
# 'SteamVR Collectibles: 1'
# 'In-App Purchases: 4'
# 'Valve Anti-Cheat enabled: 3'
# 'Single-player: 6'
# 'MMO: 1'
# 'PvP: 5'
# 'Online PvP: 5'
# 'Steam Achievements: 6'
# 'Full controller support: 5'
# 'Remote Play on Tablet: 7'
# 'Stats: 3'
# 'Remote Play on Phone: 3'
# 'Remote Play on TV: 3'
# 'Cross-Platform Multiplayer: 4'
# 'Online Co-op: 5'
# 'Steam Cloud: 5'
# 'Shared/Split Screen PvP: 2'
# 'Shared/Split Screen Co-op: 2'
# 'Shared/Split Screen: 2'
# 'Captions available: 2'
# 'Includes level editor: 2'
# 'Remote Play Together: 2'
# 'Partial Controller Support: 1'
# 'Commentary available: 1'
# 'LAN PvP: 1'
# 'LAN Co-op: 1'

# %%
# app_temp_genres = []
# app_temp_categories = []

for game in sorted_games[:10]:
    
    app_temp_genres = []
    app_temp_categories = []
    
    app_id = game['appid']
    app_name = game['name']
    playtime_forever = game['playtime_forever']
    playtime_hours = playtime_forever / 60
    

    for item in apps_data[app_id][str(app_id)]["data"]["genres"]:
        genre = item["description"]
        app_temp_genres.append(genre)
        
    for item in apps_data[app_id][str(app_id)]["data"]["categories"]:
        categories = item["description"]
        app_temp_categories.append(categories)

    print("app_id:", app_id, " - ", app_name, " - Total Playtime:", playtime_forever, "or", round(playtime_hours), "hours.", app_temp_genres, app_temp_categories)
# Out:
# app_id: 570  -  Dota 2  - Total Playtime: 180723 or 3012 hours. ['Action', 'Free to Play', 'Strategy'] ['Multi-player', 'Co-op', 'Steam Trading Cards', 'Steam Workshop', 'SteamVR Collectibles', 'In-App Purchases', 'Valve Anti-Cheat enabled']
# app_id: 238960  -  Path of Exile  - Total Playtime: 91380 or 1523 hours. ['Action', 'Adventure', 'Free to Play', 'Indie', 'Massively Multiplayer', 'RPG'] ['Single-player', 'Multi-player', 'MMO', 'PvP', 'Online PvP', 'Co-op', 'Steam Achievements', 'Full controller support', 'Steam Trading Cards', 'In-App Purchases', 'Remote Play on Tablet']
# app_id: 730  -  Counter-Strike: Global Offensive  - Total Playtime: 41370 or 690 hours. ['Action', 'Free to Play'] ['Multi-player', 'Steam Achievements', 'Full controller support', 'Steam Trading Cards', 'Steam Workshop', 'In-App Purchases', 'Valve Anti-Cheat enabled', 'Stats', 'Remote Play on Phone', 'Remote Play on Tablet', 'Remote Play on TV']
# app_id: 393420  -  Hurtworld  - Total Playtime: 5771 or 96 hours. ['Action', 'Adventure', 'Simulation'] ['Multi-player', 'Co-op', 'Cross-Platform Multiplayer', 'Remote Play on Tablet']
# app_id: 1245620  -  ELDEN RING  - Total Playtime: 3699 or 62 hours. ['Action', 'RPG'] ['Single-player', 'Multi-player', 'PvP', 'Online PvP', 'Co-op', 'Online Co-op', 'Steam Achievements', 'Full controller support', 'Steam Trading Cards', 'Steam Cloud']
# app_id: 526870  -  Satisfactory  - Total Playtime: 3080 or 51 hours. ['Adventure', 'Indie', 'Simulation', 'Strategy', 'Early Access'] ['Single-player', 'Multi-player', 'Co-op', 'Online Co-op', 'Cross-Platform Multiplayer', 'Steam Cloud', 'Remote Play on Tablet']
# app_id: 435150  -  Divinity: Original Sin 2  - Total Playtime: 2300 or 38 hours. ['Adventure', 'RPG', 'Strategy'] ['Single-player', 'Multi-player', 'PvP', 'Online PvP', 'Shared/Split Screen PvP', 'Co-op', 'Online Co-op', 'Shared/Split Screen Co-op', 'Shared/Split Screen', 'Steam Achievements', 'Full controller support', 'Steam Trading Cards', 'Captions available', 'Steam Workshop', 'Steam Cloud', 'Includes level editor', 'Remote Play on Tablet', 'Remote Play on TV', 'Remote Play Together']
# app_id: 440  -  Team Fortress 2  - Total Playtime: 2288 or 38 hours. ['Action', 'Free to Play'] ['Multi-player', 'Cross-Platform Multiplayer', 'Steam Achievements', 'Steam Trading Cards', 'Captions available', 'Steam Workshop', 'In-App Purchases', 'Partial Controller Support', 'Valve Anti-Cheat enabled', 'Stats', 'Includes level editor', 'Commentary available', 'Remote Play on Phone', 'Remote Play on Tablet']
# app_id: 252950  -  Rocket League  - Total Playtime: 2216 or 37 hours. ['Action', 'Indie', 'Racing', 'Sports'] ['Single-player', 'Multi-player', 'PvP', 'Online PvP', 'Shared/Split Screen PvP', 'Co-op', 'Online Co-op', 'Shared/Split Screen Co-op', 'Shared/Split Screen', 'Cross-Platform Multiplayer', 'Steam Achievements', 'Full controller support', 'Steam Trading Cards', 'Steam Workshop', 'Steam Cloud', 'Stats', 'Remote Play on Phone', 'Remote Play on Tablet', 'Remote Play on TV', 'Remote Play Together']
# app_id: 1604030  -  V Rising  - Total Playtime: 1411 or 24 hours. ['Action', 'Adventure', 'Massively Multiplayer', 'Early Access'] ['Single-player', 'Multi-player', 'PvP', 'Online PvP', 'LAN PvP', 'Co-op', 'Online Co-op', 'LAN Co-op', 'Steam Cloud']

# %%
app_id
# Out:
# 1604030

# %%
from googletrans import Translator

def translate_to_english(text):
    translator = Translator()
    translation = translator.translate(text, dest='en')
    return translation.text


translated_genres = []
translated_categories = []


# Translate each string in the original list to English
for string in top_10_apps_ids_genres:
    translated_string = translate_to_english(string)
    translated_genres.append(translated_string)


for string in top_10_apps_ids_categories:
    translated_string = translate_to_english(string)
    translated_categories.append(translated_string)
    
    
    
print(translated_genres)
print(translated_categories)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 20
#      16     translated_genres.append(translated_string)
#      19 for string in top_10_apps_ids_categories:
# ---> 20     translated_string = translate_to_english(string)
#      21     translated_categories.append(translated_string)
#      25 print(translated_genres)
#
# Cell In[67], line 5, in translate_to_english(text)
#       3 def translate_to_english(text):
#       4     translator = Translator()
# ----> 5     translation = translator.translate(text, dest='en')
#       6     return translation.text
#
# File c:\Users\theya\anaconda3\lib\site-packages\googletrans\client.py:219, in Translator.translate(self, text, dest, src)
#     216         break
#     218 data = json.loads(resp)
# --> 219 parsed = json.loads(data[0][2])
#     220 # not sure
#     221 should_spacing = parsed[1][0][0][3]
#
# File c:\Users\theya\anaconda3\lib\json\__init__.py:339, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337 else:
#     338     if not isinstance(s, (bytes, bytearray)):
# --> 339         raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     340                         f'not {s.__class__.__name__}')
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
#
# TypeError: the JSON object must be str, bytes or bytearray, not NoneType

# %%
# Sort the keys based on their values in descending order
top_3_played_genres = sorted(genres_value_counts, key=lambda k: genres_value_counts[k], reverse=True)[:3]

# Print the top 5 keys and their corresponding values
print("The top 3 genres of games you usually play on the Steam platform are:")
for key in top_3_played_genres:
    pprint.pprint(f"{key}: {genres_value_counts[key]}")

# %%
# Sort the keys based on their values in descending order
top_3_played_categories = sorted(categories_value_counts, key=lambda k: categories_value_counts[k], reverse=True)[:3]

# Print the top 5 keys and their corresponding values
print("The top 3 categories of games you usually play on the Steam platform are:")
for key in top_3_played_categories:
    pprint.pprint(f"{key}: {categories_value_counts[key]}")

# %%
# Maintenant, nous pouvons utiliser l'API Steam pour trouver d'autres jeux avec
# ce genre et les recommander à l'utilisateur.

# %% [markdown]
# # ABOVE WORKS

# %%
import requests

# Replace 'YOUR_API_KEY' with your actual Steam Web API key
api_key = 'EBD4755E3413CDB394B97D5F15AAD148'

# Replace 'APP_ID' with the ID of the game you want to retrieve tags for
app_id = '10'

# URL for retrieving the list of apps
app_list_url = 'https://api.steampowered.com/ISteamApps/GetAppList/v2/'

# Make the request to get the list of apps
response = requests.get(app_list_url)

# Parse the response as JSON
data = response.json()

# Retrieve the list of apps
apps = data['applist']['apps']

# Check if the app ID is valid and tags are available
if app_id in data and 'tags' in data[app_id]['data']:
    # Retrieve the tags for the app
    tags = data[app_id]['data']['tags']

    # Print the tags
    print(f'Tags for app {app_id}:')
    for tag in tags:
        print(tag['description'])
else:
    print('App not found or tags unavailable')

# %%
# URL for retrieving the app tags
url = f'https://store.steampowered.com/api/appdetails?appids={app_id}&key={api_key}'

# Make the request to get the app tags
response = requests.get(url)

# Parse the response as JSON
data = response.json()

# Check if the app ID is valid and tags are available
if app_id in data and 'tags' in data[app_id]['data']:
    # Retrieve the tags for the app
    tags = data[app_id]['data']['tags']

    # Print the tags
    print(f'Tags for app {app_id}:')
    for tag in tags:
        print(tag['description'])
else:
    print('App not found or tags unavailable')

# %%
tags

# %%
data

# %%
apps

# %%
user_friends = steam.users.get_user_friends_list("76561198084178563")
user_friends

# %%
df = pd.DataFrame()

# Supposons que df est votre DataFrame et que 'genres' est la colonne avec la liste des genres
genres = df['genres'].apply(pd.Series)
genres = genres.rename(columns = lambda x : 'genre_' + str(x))
df = pd.concat([df[:], genres[:]], axis=1)

# %% [markdown]
# # REST OF CODE:

# %%
import requests

api_key = "EBD4755E3413CDB394B97D5F15AAD148"
steam_id = 76561198084178563

# Step 2: Get player summaries
player_summaries_url = f"https://api.steampowered.com/ISteamUser/GetPlayerSummaries/v0002/?key={api_key}&steamids={steam_id}"
response = requests.get(player_summaries_url)
player_data = response.json()

# Step 3: Extract recently played games
recent_games = player_data["response"]["players"][0].get("games", [])

# Step 4 and 5: Retrieve game details and extract genres
for game in recent_games:
    app_id = game["appid"]
    game_details_url = f"https://store.steampowered.com/api/appdetails/?appids={app_id}"
    response = requests.get(game_details_url)
    game_details = response.json()

    if game_details[str(app_id)]["success"]:
        genres = game_details[str(app_id)]["data"]["genres"]
        genre_names = [genre["description"] for genre in genres]
        print(f"Game: {game['name']}")
        print(f"Genres: {', '.join(genre_names)}")
        print()

# %%
recent_games

# %%
import requests

# Make a request to the Steam API to get the app list
url = "https://api.steampowered.com/ISteamApps/GetAppList/v2/"
response = requests.get(url)

# Extract the list of apps from the response JSON
app_list = response.json()['applist']['apps']

# Iterate over the app list and retrieve genres for each app
for app in app_list:
    app_id = app['appid']
    app_name = app['name']

    # Make a request to the Steam API to get the app details, including genres
    app_details_url = f'https://store.steampowered.com/api/appdetails?appids={app_id}'
    app_details_response = requests.get(app_details_url)

    # Extract the genres from the app details response
    app_details = app_details_response.json()
    if app_details[str(app_id)]['success']:
        genres = app_details[str(app_id)]['data']['genres']
        genre_names = [genre['description'] for genre in genres]

        print(f"App ID: {app_id}")
        print(f"App Name: {app_name}")
        print(f"Genres: {', '.join(genre_names)}")
        print('---')

# %%
# terraria_app_id = 105600
# # app_details

# # arguments: app_id
# shop_game_details = steam.apps.get_app_details(terraria_app_id)
# pprint.pprint(shop_game_details)

# %%
# user_acc_info DOES NOT WORK

user_acc_info = steam.users.search_user(persona_name)
user_acc_info

# %%
# game_user_stats DOES NOT WORK

# arguments: steam_id, app_id
game_user_stats = steam.apps.get_user_stats(user_steam_id, app_details)
game_user_stats

# %%
# user_recently_played

# arguments: steamid DOES NOT WORK
user_recently_played = steam.users.get_user_recently_played_games("76561198084178563")
user_recently_played

# %%
# user_achievements

# arguments: steam_id, app_id
user_achievements = steam.apps.get_user_achievements(
    "76561198995017863", "105600")
user_achievements

# %%
# Ceci est un exemple simplifié, en supposant que nous ayons déjà les données
# nécessaires. L'interaction avec l'API Steam pour obtenir ces données n'est
# pas montrée ici.

# Disons que nous avons les jeux auxquels l'utilisateur a joué et leurs genres
jeux_utilisateur = {
    "Half-Life 2": ["Shooter", "Action", "Sci-Fi"],
    "Portal": ["Puzzle", "Action", "Sci-Fi"],
    "The Witcher 3": ["RPG", "Action", "Fantasy"],
    # ...
}

# Comptons le nombre de fois où chaque genre apparaît
genres = {}
for jeux, genres_jeu in jeux_utilisateur.items():
    for genre in genres_jeu:
        if genre not in genres:
            genres[genre] = 0
        genres[genre] += 1

# Trouvons le genre le plus joué
genre_prefere = max(genres, key=genres.get)

# Maintenant, nous pouvons utiliser l'API Steam pour trouver d'autres jeux avec
# ce genre et les recommander à l'utilisateur.
